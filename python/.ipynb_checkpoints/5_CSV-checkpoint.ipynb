# %%
import numpy as np
import pandas as pd

# %%
df=pd.read_csv('mt_cars.csv')
df
# Out:
#                   model   mpg  cyl   disp     hp  drat     wt   qsec  vs  am  \
# 0             Mazda RX4  21.0    6  160.0  110.0  3.90  2.620  16.46   0   1
# 1         Mazda RX4 Wag  21.0    6  160.0  110.0  3.90  2.875  17.02   0   1
# 2            Datsun 710  22.8    4  108.0   93.0  3.85  2.320  18.61   1   1
# 3        Hornet 4 Drive  21.4    6  258.0  110.0  3.08  3.215  19.44   1   0
# 4     Hornet Sportabout   NaN    8  360.0  175.0  3.15  3.440  17.02   0   0
# 5               Valiant  18.1    6  225.0  105.0  2.76  3.460  20.22   1   0
# 6            Duster 360  14.3    8  360.0  245.0   NaN  3.570  15.84   0   0
# 7             Merc 240D  24.4    4  146.7   62.0  3.69  3.190  20.00   1   0
# 8              Merc 230  22.8    4  140.8   95.0   NaN  3.150  22.90   1   0
# 9              Merc 280  19.2    6    NaN  123.0  3.92  3.440  18.30   1   0
# 10            Merc 280C  17.8    6  167.6    NaN  3.92  3.440  18.90   1   0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32 entries, 0 to 31
# Data columns (total 12 columns):
# model    32 non-null object
# mpg      27 non-null float64
# cyl      32 non-null int64
# disp     24 non-null float64
# hp       25 non-null float64
# drat     26 non-null float64
# wt       28 non-null float64
# qsec     31 non-null float64
# vs       32 non-null int64
# am       32 non-null int64
# gear     32 non-null int64
# carb     32 non-null int64
# dtypes: float64(6), int64(5), object(1)
# memory usage: 3.1+ KB

# %%
df.describe()
# Out:
#              mpg        cyl        disp          hp       drat         wt  \
# count  27.000000  32.000000   24.000000   25.000000  26.000000  28.000000
# mean   20.837037   6.187500  221.562500  144.560000   3.601154   3.142214
# std     6.241434   1.785922  113.793584   71.690934   0.537917   0.959747
# min    10.400000   4.000000   71.100000   52.000000   2.760000   1.513000
# 25%    15.950000   4.000000  135.625000   95.000000   3.097500   2.428750
# 50%    21.000000   6.000000  196.300000  113.000000   3.695000   3.325000
# 75%    23.600000   8.000000  301.750000  175.000000   3.915000   3.570000
# max    33.900000   8.000000  460.000000  335.000000   4.930000   5.424000
#
#             qsec         vs         am       gear     carb
# count  31.000000  32.000000  32.000000  32.000000  32.0000
# mean   17.782581   0.437500   0.406250   3.687500   2.8125
# std     1.776183   0.504016   0.498991   0.737804   1.6152
# min    14.500000   0.000000   0.000000   3.000000   1.0000
# ...

# %%
df.isnull().sum()
# Out:
# model    0
# mpg      5
# cyl      0
# disp     8
# hp       7
# drat     6
# wt       4
# qsec     1
# vs       0
# am       0
# gear     0
# carb     0
# dtype: int64

# %%
df.isnull().sum().sum()
# Out:
# 31

# %%
df.shape
# Out:
# (32, 12)

# %%
df.isnull().sum(axis=is=1)
# Out:
# 0     0
# 1     0
# 2     0
# 3     0
# 4     1
# 5     0
# 6     1
# 7     0
# 8     1
# 9     1
# 10    1
# 11    1
# 12    2
# 13    2
# 14    4
# 15    0
# 16    2
# 17    0
# 18    1
# 19    3
# 20    1
# 21    1
# 22    1
# 23    1
# 24    0
# 25    0
# 26    1
# 27    0
# 28    3
# 29    1
# 30    0
# 31    2
# dtype: int64

# %%
round(df.isnull().sum()/len(df)*100,2)
# Out:
# model     0.00
# mpg      15.62
# cyl       0.00
# disp     25.00
# hp       21.88
# drat     18.75
# wt       12.50
# qsec      3.12
# vs        0.00
# am        0.00
# gear      0.00
# carb      0.00
# dtype: float64

# %%
df['mpg'].value_counts()
# Out:
# 21.0    2
# 19.2    2
# 30.4    2
# 21.4    2
# 10.4    2
# 22.8    2
# 14.7    1
# 21.5    1
# 15.5    1
# 17.8    1
# 26.0    1
# 15.0    1
# 27.3    1
# 15.2    1
# 14.3    1
# 33.9    1
# 18.1    1
# 24.4    1
# 19.7    1
# 16.4    1
# 32.4    1
# Name: mpg, dtype: int64

# %%
df['hp'].isnull().sum()
# Out:
# 7

# %%
np.isnan(df['hp']).sum()
# Out:
# 7

# %%
df=df[~np.isnan(df['hp'])]

# %%
df.shape
# Out:
# (25, 12)

# %%
df.drop('gear',axis=1)
# Out:
#                   model   mpg  cyl   disp     hp  drat     wt   qsec  vs  am  \
# 0             Mazda RX4  21.0    6  160.0  110.0  3.90  2.620  16.46   0   1
# 1         Mazda RX4 Wag  21.0    6  160.0  110.0  3.90  2.875  17.02   0   1
# 2            Datsun 710  22.8    4  108.0   93.0  3.85  2.320  18.61   1   1
# 3        Hornet 4 Drive  21.4    6  258.0  110.0  3.08  3.215  19.44   1   0
# 4     Hornet Sportabout   NaN    8  360.0  175.0  3.15  3.440  17.02   0   0
# 5               Valiant  18.1    6  225.0  105.0  2.76  3.460  20.22   1   0
# 6            Duster 360  14.3    8  360.0  245.0   NaN  3.570  15.84   0   0
# 7             Merc 240D  24.4    4  146.7   62.0  3.69  3.190  20.00   1   0
# 8              Merc 230  22.8    4  140.8   95.0   NaN  3.150  22.90   1   0
# 9              Merc 280  19.2    6    NaN  123.0  3.92  3.440  18.30   1   0
# 12           Merc 450SL   NaN    8  275.8  180.0   NaN  3.730  17.60   0   0
# ...

# %%
df.isnull().sum()
# Out:
# model    0
# mpg      5
# cyl      0
# disp     6
# hp       0
# drat     4
# wt       2
# qsec     0
# vs       0
# am       0
# gear     0
# carb     0
# dtype: int64

# %%
df.fillna(value='NULL_VALUE')
# Out:
#                   model         mpg  cyl        disp     hp        drat  \
# 0             Mazda RX4          21    6         160  110.0         3.9
# 1         Mazda RX4 Wag          21    6         160  110.0         3.9
# 2            Datsun 710        22.8    4         108   93.0        3.85
# 3        Hornet 4 Drive        21.4    6         258  110.0        3.08
# 4     Hornet Sportabout  NULL_VALUE    8         360  175.0        3.15
# 5               Valiant        18.1    6         225  105.0        2.76
# 6            Duster 360        14.3    8         360  245.0  NULL_VALUE
# 7             Merc 240D        24.4    4       146.7   62.0        3.69
# 8              Merc 230        22.8    4       140.8   95.0  NULL_VALUE
# 9              Merc 280        19.2    6  NULL_VALUE  123.0        3.92
# 12           Merc 450SL  NULL_VALUE    8       275.8  180.0  NULL_VALUE
# 15  Lincoln Continental        10.4    8         460  215.0           3
# ...

# %%
df['mpg'].fillna(value=df['mpg'].mean(),inplace=True)
# Out:
# C:\Users\User\Anaconda3\lib\site-packages\pandas\core\generic.py:6130: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._update_inplace(new_data)

# %%
df['mpg'].isnull().sum()
# Out:
# 0

# %%
df.fillna(method='ffill',inplace=True)

# %%
df.isnull().sum()
# Out:
# model    0
# mpg      0
# cyl      0
# disp     0
# hp       0
# drat     0
# wt       0
# qsec     0
# vs       0
# am       0
# gear     0
# carb     0
# dtype: int64

# %%
df[df['mpg']>22][['wt']]
# Out:
#        wt
# 2   2.320
# 7   3.190
# 8   3.150
# 17  2.200
# 18  1.615
# 25  1.935
# 26  2.140
# 27  1.513

# %%
df['new mpg']=df.apply(lambda x: 'low' if x.mpg<19 else 'medium' ,axis=1)
# Out:
# C:\Users\User\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
df
# Out:
#                   model     mpg  cyl   disp     hp  drat     wt   qsec  vs  \
# 0             Mazda RX4  21.000    6  160.0  110.0  3.90  2.620  16.46   0
# 1         Mazda RX4 Wag  21.000    6  160.0  110.0  3.90  2.875  17.02   0
# 2            Datsun 710  22.800    4  108.0   93.0  3.85  2.320  18.61   1
# 3        Hornet 4 Drive  21.400    6  258.0  110.0  3.08  3.215  19.44   1
# 4     Hornet Sportabout  21.635    8  360.0  175.0  3.15  3.440  17.02   0
# 5               Valiant  18.100    6  225.0  105.0  2.76  3.460  20.22   1
# 6            Duster 360  14.300    8  360.0  245.0  3.69  3.570  15.84   0
# 7             Merc 240D  24.400    4  146.7   62.0  3.69  3.190  20.00   1
# 8              Merc 230  22.800    4  140.8   95.0  3.92  3.150  22.90   1
# 9              Merc 280  19.200    6  275.8  123.0  3.92  3.440  18.30   1
# 12           Merc 450SL  21.635    8  275.8  180.0  3.00  3.730  17.60   0
# ...

# %%
df.mpg
# Out:
# 0     21.000
# 1     21.000
# 2     22.800
# 3     21.400
# 4     21.635
# 5     18.100
# 6     14.300
# 7     24.400
# 8     22.800
# 9     19.200
# 12    21.635
# 15    10.400
# 17    32.400
# 18    30.400
# 21    15.500
# 22    21.635
# 23    21.635
# 24    19.200
# 25    27.300
# 26    26.000
# 27    30.400
# 28    21.635
# 29    19.700
# 30    15.000
# 31    21.400
# Name: mpg, dtype: float64

# %%
df['new mpg']=df.apply(lambda x: 'low' if x.mpg<19 else ('medium' if (x.mpg<24) else 'high'),axis=1)
# Out:
# C:\Users\User\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
df.apply(lambda x:'increased' if x.mpg>x.qsec else('not_changed' if x.mpg==x.qsec else 'dec'),axis=1)
# Out:
# 0     increased
# 1     increased
# 2     increased
# 3     increased
# 4     increased
# 5           dec
# 6           dec
# 7     increased
# 8           dec
# 9     increased
# 12    increased
# 15          dec
# 17    increased
# 18    increased
# 21          dec
# 22    increased
# 23    increased
# 24    increased
# 25    increased
# 26    increased
# 27    increased
# 28    increased
# 29    increased
# 30    increased
# 31    increased
# dtype: object

# %%
df.apply(lambda x:'increased' if x.mpg<20 else('not_changed' if (x.mpg>20) & (x.mpg<24) else 'dec'),axis=1)
# Out:
# 0     not_changed
# 1     not_changed
# 2     not_changed
# 3     not_changed
# 4     not_changed
# 5       increased
# 6       increased
# 7             dec
# 8     not_changed
# 9       increased
# 12    not_changed
# 15      increased
# 17            dec
# 18            dec
# 21      increased
# 22    not_changed
# 23    not_changed
# 24      increased
# 25            dec
# 26            dec
# 27            dec
# 28    not_changed
# 29      increased
# 30      increased
# 31    not_changed
# dtype: object

# %%
df
# Out:
#                   model     mpg  cyl   disp     hp  drat     wt   qsec  vs  \
# 0             Mazda RX4  21.000    6  160.0  110.0  3.90  2.620  16.46   0
# 1         Mazda RX4 Wag  21.000    6  160.0  110.0  3.90  2.875  17.02   0
# 2            Datsun 710  22.800    4  108.0   93.0  3.85  2.320  18.61   1
# 3        Hornet 4 Drive  21.400    6  258.0  110.0  3.08  3.215  19.44   1
# 4     Hornet Sportabout  21.635    8  360.0  175.0  3.15  3.440  17.02   0
# 5               Valiant  18.100    6  225.0  105.0  2.76  3.460  20.22   1
# 6            Duster 360  14.300    8  360.0  245.0  3.69  3.570  15.84   0
# 7             Merc 240D  24.400    4  146.7   62.0  3.69  3.190  20.00   1
# 8              Merc 230  22.800    4  140.8   95.0  3.92  3.150  22.90   1
# 9              Merc 280  19.200    6  275.8  123.0  3.92  3.440  18.30   1
# 12           Merc 450SL  21.635    8  275.8  180.0  3.00  3.730  17.60   0
# ...
