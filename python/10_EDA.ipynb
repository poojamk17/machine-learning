# %%
import warnings
warnings.filterwarnings('ignore')

# %%
import numpy as np
import pandas as pd 
import seaborn as sns
import matplotlib.pyplot as plt
# import statistics as st
from scipy import stats as st
# %matplotlib inline

# %%
df1=pd.read_csv('titanic.csv')
df1.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
# PassengerId    891 non-null int64
# Survived       891 non-null int64
# Pclass         891 non-null int64
# Name           891 non-null object
# Sex            891 non-null object
# Age            714 non-null float64
# SibSp          891 non-null int64
# Parch          891 non-null int64
# Ticket         891 non-null object
# Fare           891 non-null float64
# Cabin          204 non-null object
# Embarked       889 non-null object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.6+ KB

# %%
df1.shape
# Out:
# (891, 12)

# %%
df1.columns#
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
df1.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
df1.drop('PassengerId',axis=1,inplace=True)

# %%
df1.shape
# Out:
# (891, 11)

# %%
df1['Age'].fillna(value=df1['Age'].mean(),inplace=True)

# %%
df1['Cabin'].fillna(method='bfill',inplace=True)

# %%
df1['Embarked'].fillna(method='bfill',inplace=True)

# %%
df1.isnull().sum()
# Out:
# Survived    0
# Pclass      0
# Name        0
# Sex         0
# Age         0
# SibSp       0
# Parch       0
# Ticket      0
# Fare        0
# Cabin       1
# Embarked    0
# dtype: int64

# %%
df1['Cabin'].fillna(method='ffill',inplace=True)

# %%
df1.isnull().sum()
# Out:
# Survived    0
# Pclass      0
# Name        0
# Sex         0
# Age         0
# SibSp       0
# Parch       0
# Ticket      0
# Fare        0
# Cabin       0
# Embarked    0
# dtype: int64

# %%
df1.describe()
# Out:
#          Survived      Pclass         Age       SibSp       Parch        Fare
# count  891.000000  891.000000  891.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.699118    0.523008    0.381594   32.204208
# std      0.486592    0.836071   13.002015    1.102743    0.806057   49.693429
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   22.000000    0.000000    0.000000    7.910400
# 50%      0.000000    3.000000   29.699118    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   35.000000    1.000000    0.000000   31.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %%
df1.skew()
# Out:
# Survived    0.478523
# Pclass     -0.630548
# Age         0.434488
# SibSp       3.695352
# Parch       2.749117
# Fare        4.787317
# dtype: float64

# %%
df1.kurtosis()
# Out:
# Survived    -1.775005
# Pclass      -1.280015
# Age          0.966279
# SibSp       17.880420
# Parch        9.778125
# Fare        33.398141
# dtype: float64

# %%
st.iqr(df1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\scipy\stats\stats.py in _iqr_percentile(x, q, axis, interpolation, keepdims, contains_nan)
#    2521         result = np.percentile(x, q, axis=axis, keepdims=keepdims,
# -> 2522                                interpolation=interpolation)
#    2523     except TypeError:
#
# ~\Anaconda3\lib\site-packages\numpy\lib\function_base.py in percentile(a, q, axis, out, overwrite_input, interpolation, keepdims)
#    3706     return _quantile_unchecked(
# -> 3707         a, q, axis, out, overwrite_input, interpolation, keepdims)
#    3708
#
# ~\Anaconda3\lib\site-packages\numpy\lib\function_base.py in _quantile_unchecked(a, q, axis, out, overwrite_input, interpolation, keepdims)
#    3825                     overwrite_input=overwrite_input,
# -> 3826                     interpolation=interpolation)
# ...

# %%
df1.plot(kind='bar')

# %%
df1.plot(kind='hist')

# %%
sns.distplot(df1['Survived'])

# %%
sns.heatmap(df1.corr(),annot=True)

# %%
sns.pairplot(df1)

# %%
plt.scatter(df1['Survived'],df1['Pclass'])

# %%
st.zscore(df1['Pclass'])
# Out:
# array([ 0.82737724, -1.56610693,  0.82737724, -1.56610693,  0.82737724,
#         0.82737724, -1.56610693,  0.82737724,  0.82737724, -0.36936484,
#         0.82737724, -1.56610693,  0.82737724,  0.82737724,  0.82737724,
#        -0.36936484,  0.82737724, -0.36936484,  0.82737724,  0.82737724,
#        -0.36936484, -0.36936484,  0.82737724, -1.56610693,  0.82737724,
#         0.82737724,  0.82737724, -1.56610693,  0.82737724,  0.82737724,
#        -1.56610693, -1.56610693,  0.82737724, -0.36936484, -1.56610693,
#        -1.56610693,  0.82737724,  0.82737724,  0.82737724,  0.82737724,
#         0.82737724, -0.36936484,  0.82737724, -0.36936484,  0.82737724,
#         0.82737724,  0.82737724,  0.82737724,  0.82737724,  0.82737724,
#         0.82737724,  0.82737724, -1.56610693, -0.36936484, -1.56610693,
#        -1.56610693, -0.36936484,  0.82737724, -0.36936484,  0.82737724,
#         0.82737724, -1.56610693, -1.56610693,  0.82737724, -1.56610693,
# ...

# %%
df1['Pclass'].corr(df1['Survived'])
# Out:
# -0.3384810359610147
