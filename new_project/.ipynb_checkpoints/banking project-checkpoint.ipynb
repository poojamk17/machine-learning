# %%
import pandas as pd
import numpy as np

# %%
df1=pd.read_csv("file-3.csv")
df1
# Out:
#                   category_list  Automotive & Sports  Blanks  \
# 0                           NaN                    0       1
# 1                            3D                    0       0
# 2                   3D Printing                    0       0
# 3                 3D Technology                    0       0
# 4                    Accounting                    0       0
# 5              Active Lifestyle                    0       0
# 6                  Ad Targeting                    0       0
# 7            Advanced Materials                    0       0
# 8              Adventure Travel                    1       0
# 9                   Advertising                    0       0
# 10        Advertising Exchanges                    0       0
# 11         Advertising Networks                    0       0
# 12        Advertising Platforms                    0       0
# 13                       Advice                    0       0
# ...

# %%
df2=pd.read_table("company.txt",encoding='unicode_escape')
df2
# Out:
# C:\Users\Hp\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: read_table is deprecated, use read_csv instead, passing sep='\t'.
#   """Entry point for launching an IPython kernel.
#                                                permalink  \
# 0                                    /Organization/-Fame
# 1                                 /Organization/-Qounter
# 2                    /Organization/-The-One-Of-Them-Inc-
# 3                                  /Organization/0-6-Com
# 4                         /Organization/004-Technologies
# 5                       /Organization/01Games-Technology
# 6                    /Organization/0Ndine-Biomedical-Inc
# 7                                   /Organization/0Xdata
# 8                                        /Organization/1
# 9                              /Organization/1-2-3-Listo
# 10                                 /Organization/1-4-All
# 11                        /Organization/1-618-Technology
# ...

# %% [markdown]
# #### permalink in a company data frame is a unique key that is used for each company

# %%
len(df2['permalink'].value_counts())
# Out:
# 66368

# %%
df3=pd.read_csv("file-2.csv",encoding='unicode escape')
df3
# Out:
#                                         company_permalink  \
# 0                                     /organization/-fame
# 1                                  /ORGANIZATION/-QOUNTER
# 2                                  /organization/-qounter
# 3                     /ORGANIZATION/-THE-ONE-OF-THEM-INC-
# 4                                   /organization/0-6-com
# 5                          /ORGANIZATION/004-TECHNOLOGIES
# 6                        /organization/01games-technology
# 7                     /ORGANIZATION/0NDINE-BIOMEDICAL-INC
# 8                     /organization/0ndine-biomedical-inc
# 9                                    /ORGANIZATION/0XDATA
# 10                                   /organization/0xdata
# 11                                   /ORGANIZATION/0XDATA
# 12                                   /organization/0xdata
# 13                                        /ORGANIZATION/1
# 14                                        /organization/1
# ...

# %%
df2.isnull().sum()
# Out:
# permalink            0
# name                 1
# homepage_url      5058
# category_list     3148
# status               0
# country_code      6958
# state_code        8547
# region            8030
# city              8028
# founded_at       15221
# dtype: int64

# %%
df2['name'].fillna(value='testyantra',inplace=True)
df2
# Out:
#                                                permalink  \
# 0                                    /Organization/-Fame
# 1                                 /Organization/-Qounter
# 2                    /Organization/-The-One-Of-Them-Inc-
# 3                                  /Organization/0-6-Com
# 4                         /Organization/004-Technologies
# 5                       /Organization/01Games-Technology
# 6                    /Organization/0Ndine-Biomedical-Inc
# 7                                   /Organization/0Xdata
# 8                                        /Organization/1
# 9                              /Organization/1-2-3-Listo
# 10                                 /Organization/1-4-All
# 11                        /Organization/1-618-Technology
# 12                           /Organization/1-800-Dentist
# 13                           /Organization/1-800-Doctors
# 14              /Organization/1-800-Publicrelations-Inc-
# ...

# %%
df2.isnull().sum()
# Out:
# permalink            0
# name                 0
# homepage_url      5058
# category_list     3148
# status               0
# country_code      6958
# state_code        8547
# region            8030
# city              8028
# founded_at       15221
# dtype: int64

# %% [markdown]
# #### unique company names in company data frames

# %%
len(df2['name'].value_counts())
# Out:
# 66103

# %% [markdown]
# #### unique company names in file2

# %%
df3.isnull().sum()
# Out:
# company_permalink              0
# funding_round_permalink        0
# funding_round_type             0
# funding_round_code         83809
# funded_at                      0
# raised_amount_usd          19990
# dtype: int64

# %% [markdown]
# ####  unique company name for file2

# %%
len(df3['company_permalink'].value_counts())
# Out:
# 90247

# %%
list=df2['permalink'].tolist()
list
# Out:
# ['/Organization/-Fame',
#  '/Organization/-Qounter',
#  '/Organization/-The-One-Of-Them-Inc-',
#  '/Organization/0-6-Com',
#  '/Organization/004-Technologies',
#  '/Organization/01Games-Technology',
#  '/Organization/0Ndine-Biomedical-Inc',
#  '/Organization/0Xdata',
#  '/Organization/1',
#  '/Organization/1-2-3-Listo',
#  '/Organization/1-4-All',
#  '/Organization/1-618-Technology',
#  '/Organization/1-800-Dentist',
#  '/Organization/1-800-Doctors',
#  '/Organization/1-800-Publicrelations-Inc-',
#  '/Organization/1-Mainstream',
#  '/Organization/1-Of-99',
#  '/Organization/10-20-Media',
#  '/Organization/10-Minutes-With',
#  '/Organization/1000-Corks',
#  '/Organization/1000-Markets',
#  '/Organization/1000Chi',
#  '/Organization/1000Lookz',
#  '/Organization/1000Memories',
#  '/Organization/1000Museums-Com',
#  '/Organization/1001-Menus',
#  '/Organization/1001Pharmacies-Com',
#  '/Organization/1006-Tv',
#  '/Organization/100Du-Tv',
#  '/Organization/100E-Com',
# ...

# %%
df3['company_permalink']=df3['company_permalink'].str.lower()
df3
# Out:
#                                         company_permalink  \
# 0                                     /organization/-fame
# 1                                  /organization/-qounter
# 2                                  /organization/-qounter
# 3                     /organization/-the-one-of-them-inc-
# 4                                   /organization/0-6-com
# 5                          /organization/004-technologies
# 6                        /organization/01games-technology
# 7                     /organization/0ndine-biomedical-inc
# 8                     /organization/0ndine-biomedical-inc
# 9                                    /organization/0xdata
# 10                                   /organization/0xdata
# 11                                   /organization/0xdata
# 12                                   /organization/0xdata
# 13                                        /organization/1
# 14                                        /organization/1
# ...

# %%
df2['permalink']=df2['permalink'].str.lower()
df2
# Out:
#                                                permalink  \
# 0                                    /organization/-fame
# 1                                 /organization/-qounter
# 2                    /organization/-the-one-of-them-inc-
# 3                                  /organization/0-6-com
# 4                         /organization/004-technologies
# 5                       /organization/01games-technology
# 6                    /organization/0ndine-biomedical-inc
# 7                                   /organization/0xdata
# 8                                        /organization/1
# 9                              /organization/1-2-3-listo
# 10                                 /organization/1-4-all
# 11                        /organization/1-618-technology
# 12                           /organization/1-800-dentist
# 13                           /organization/1-800-doctors
# 14              /organization/1-800-publicrelations-inc-
# ...

# %%
df3['unique']=df3.apply(lambda x:1 if x.df2['permalink']!=x.df3['company_permalink'] else 0 ,axis=1)
df3
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-95-45a48ea68e8e> in <module>
# ----> 1 df3['unique']=df3.apply(lambda x:1 if x.df2['permalink']!=x.df3['company_permalink'] else 0 ,axis=1)
#       2 df3
#       3
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in apply(self, func, axis, broadcast, raw, reduce, result_type, args, **kwds)
#    6485                          args=args,
#    6486                          kwds=kwds)
# -> 6487         return op.get_result()
#    6488
#    6489     def applymap(self, func):
#
# ~\Anaconda3\lib\site-packages\pandas\core\apply.py in get_result(self)
#     149             return self.apply_raw()
#     150
# --> 151         return self.apply_standard()
#     152
#     153     def apply_empty_result(self):
#
# ~\Anaconda3\lib\site-packages\pandas\core\apply.py in apply_standard(self)
#     255
# ...

# %%
li=[]
def fun(lis1,lis):
    for i in range(0,len(lis1)):
        for j in range(0,len(lis)):
            if(lis(i)!=lis(j)):
                li=lis(i)
                j+=1
        i+=1 
fun(list1,list)

# %%
df3.isnull().sum()

# %%
df3['funding_round_code'].fillna(method='ffill',inplace=True)
df3
# Out:
#                                                 permalink  \
# 0                                     /organization/-fame
# 1                                  /organization/-qounter
# 2                                  /organization/-qounter
# 3                     /organization/-the-one-of-them-inc-
# 4                                   /organization/0-6-com
# 5                          /organization/004-technologies
# 6                        /organization/01games-technology
# 7                     /organization/0ndine-biomedical-inc
# 8                     /organization/0ndine-biomedical-inc
# 9                                    /organization/0xdata
# 10                                   /organization/0xdata
# 11                                   /organization/0xdata
# 12                                   /organization/0xdata
# 13                                        /organization/1
# 14                                        /organization/1
# ...

# %%
df3.isnull().sum()
# Out:
# permalink                      0
# funding_round_permalink        0
# funding_round_type             0
# funding_round_code             0
# funded_at                      0
# raised_amount_usd          19990
# dtype: int64

# %%
df3['raised_amount_usd'].fillna(method='bfill',inplace=True)
df3
# Out:
#                                                 permalink  \
# 0                                     /organization/-fame
# 1                                  /organization/-qounter
# 2                                  /organization/-qounter
# 3                     /organization/-the-one-of-them-inc-
# 4                                   /organization/0-6-com
# 5                          /organization/004-technologies
# 6                        /organization/01games-technology
# 7                     /organization/0ndine-biomedical-inc
# 8                     /organization/0ndine-biomedical-inc
# 9                                    /organization/0xdata
# 10                                   /organization/0xdata
# 11                                   /organization/0xdata
# 12                                   /organization/0xdata
# 13                                        /organization/1
# 14                                        /organization/1
# ...

# %%
df3.isnull().sum()
# Out:
# permalink                  0
# funding_round_permalink    0
# funding_round_type         0
# funding_round_code         0
# funded_at                  0
# raised_amount_usd          0
# dtype: int64

# %%
df2.isnull().sum()
# Out:
# permalink            0
# name                 0
# homepage_url      5058
# category_list     3148
# status               0
# country_code      6958
# state_code        8547
# region            8030
# city              8028
# founded_at       15221
# dtype: int64

# %%
df2['homepage_url'].fillna(method='bfill',inplace=True)
df2
# Out:
#                                                permalink  \
# 0                                    /organization/-fame
# 1                                 /organization/-qounter
# 2                    /organization/-the-one-of-them-inc-
# 3                                  /organization/0-6-com
# 4                         /organization/004-technologies
# 5                       /organization/01games-technology
# 6                    /organization/0ndine-biomedical-inc
# 7                                   /organization/0xdata
# 8                                        /organization/1
# 9                              /organization/1-2-3-listo
# 10                                 /organization/1-4-all
# 11                        /organization/1-618-technology
# 12                           /organization/1-800-dentist
# 13                           /organization/1-800-doctors
# 14              /organization/1-800-publicrelations-inc-
# ...

# %%
df2['category_list'].fillna(method='ffill',inplace=True)
df2
# Out:
#                                                permalink  \
# 0                                    /organization/-fame
# 1                                 /organization/-qounter
# 2                    /organization/-the-one-of-them-inc-
# 3                                  /organization/0-6-com
# 4                         /organization/004-technologies
# 5                       /organization/01games-technology
# 6                    /organization/0ndine-biomedical-inc
# 7                                   /organization/0xdata
# 8                                        /organization/1
# 9                              /organization/1-2-3-listo
# 10                                 /organization/1-4-all
# 11                        /organization/1-618-technology
# 12                           /organization/1-800-dentist
# 13                           /organization/1-800-doctors
# 14              /organization/1-800-publicrelations-inc-
# ...

# %%
df2['country_code'].fillna(method='ffill',inplace=True)
df2
# Out:
#                                                permalink  \
# 0                                    /organization/-fame
# 1                                 /organization/-qounter
# 2                    /organization/-the-one-of-them-inc-
# 3                                  /organization/0-6-com
# 4                         /organization/004-technologies
# 5                       /organization/01games-technology
# 6                    /organization/0ndine-biomedical-inc
# 7                                   /organization/0xdata
# 8                                        /organization/1
# 9                              /organization/1-2-3-listo
# 10                                 /organization/1-4-all
# 11                        /organization/1-618-technology
# 12                           /organization/1-800-dentist
# 13                           /organization/1-800-doctors
# 14              /organization/1-800-publicrelations-inc-
# ...

# %%
df2['state_code'].fillna(method='ffill',inplace=True)
df2
# Out:
#                                                permalink  \
# 0                                    /organization/-fame
# 1                                 /organization/-qounter
# 2                    /organization/-the-one-of-them-inc-
# 3                                  /organization/0-6-com
# 4                         /organization/004-technologies
# 5                       /organization/01games-technology
# 6                    /organization/0ndine-biomedical-inc
# 7                                   /organization/0xdata
# 8                                        /organization/1
# 9                              /organization/1-2-3-listo
# 10                                 /organization/1-4-all
# 11                        /organization/1-618-technology
# 12                           /organization/1-800-dentist
# 13                           /organization/1-800-doctors
# 14              /organization/1-800-publicrelations-inc-
# ...

# %%
df2['region'].fillna(method='bfill',inplace=True)
df2
# Out:
#                                                permalink  \
# 0                                    /organization/-fame
# 1                                 /organization/-qounter
# 2                    /organization/-the-one-of-them-inc-
# 3                                  /organization/0-6-com
# 4                         /organization/004-technologies
# 5                       /organization/01games-technology
# 6                    /organization/0ndine-biomedical-inc
# 7                                   /organization/0xdata
# 8                                        /organization/1
# 9                              /organization/1-2-3-listo
# 10                                 /organization/1-4-all
# 11                        /organization/1-618-technology
# 12                           /organization/1-800-dentist
# 13                           /organization/1-800-doctors
# 14              /organization/1-800-publicrelations-inc-
# ...

# %%
df2['city'].fillna(method='ffill',inplace=True)
df2
# Out:
#                                                permalink  \
# 0                                    /organization/-fame
# 1                                 /organization/-qounter
# 2                    /organization/-the-one-of-them-inc-
# 3                                  /organization/0-6-com
# 4                         /organization/004-technologies
# 5                       /organization/01games-technology
# 6                    /organization/0ndine-biomedical-inc
# 7                                   /organization/0xdata
# 8                                        /organization/1
# 9                              /organization/1-2-3-listo
# 10                                 /organization/1-4-all
# 11                        /organization/1-618-technology
# 12                           /organization/1-800-dentist
# 13                           /organization/1-800-doctors
# 14              /organization/1-800-publicrelations-inc-
# ...

# %%
df2['founded_at'].fillna(method='ffill',inplace=True)
df2
# Out:
#                                                permalink  \
# 0                                    /organization/-fame
# 1                                 /organization/-qounter
# 2                    /organization/-the-one-of-them-inc-
# 3                                  /organization/0-6-com
# 4                         /organization/004-technologies
# 5                       /organization/01games-technology
# 6                    /organization/0ndine-biomedical-inc
# 7                                   /organization/0xdata
# 8                                        /organization/1
# 9                              /organization/1-2-3-listo
# 10                                 /organization/1-4-all
# 11                        /organization/1-618-technology
# 12                           /organization/1-800-dentist
# 13                           /organization/1-800-doctors
# 14              /organization/1-800-publicrelations-inc-
# ...

# %%
df2.isnull().sum()
# Out:
# permalink        0
# name             0
# homepage_url     0
# category_list    0
# status           0
# country_code     0
# state_code       0
# region           1
# city             0
# founded_at       1
# dtype: int64

# %%
df2['region'].fillna(method='ffill',inplace=True)
df2
# Out:
#                                                permalink  \
# 0                                    /organization/-fame
# 1                                 /organization/-qounter
# 2                    /organization/-the-one-of-them-inc-
# 3                                  /organization/0-6-com
# 4                         /organization/004-technologies
# 5                       /organization/01games-technology
# 6                    /organization/0ndine-biomedical-inc
# 7                                   /organization/0xdata
# 8                                        /organization/1
# 9                              /organization/1-2-3-listo
# 10                                 /organization/1-4-all
# 11                        /organization/1-618-technology
# 12                           /organization/1-800-dentist
# 13                           /organization/1-800-doctors
# 14              /organization/1-800-publicrelations-inc-
# ...

# %%
df2.isnull().sum()
# Out:
# permalink        0
# name             0
# homepage_url     0
# category_list    0
# status           0
# country_code     0
# state_code       0
# region           0
# city             0
# founded_at       1
# dtype: int64

# %%
df2['founded_at'].fillna(method='ffill',inplace=True)
df2
# Out:
#                                                permalink  \
# 0                                    /organization/-fame
# 1                                 /organization/-qounter
# 2                    /organization/-the-one-of-them-inc-
# 3                                  /organization/0-6-com
# 4                         /organization/004-technologies
# 5                       /organization/01games-technology
# 6                    /organization/0ndine-biomedical-inc
# 7                                   /organization/0xdata
# 8                                        /organization/1
# 9                              /organization/1-2-3-listo
# 10                                 /organization/1-4-all
# 11                        /organization/1-618-technology
# 12                           /organization/1-800-dentist
# 13                           /organization/1-800-doctors
# 14              /organization/1-800-publicrelations-inc-
# ...

# %%
df2.isnull().sum()
# Out:
# permalink        0
# name             0
# homepage_url     0
# category_list    0
# status           0
# country_code     0
# state_code       0
# region           0
# city             0
# founded_at       1
# dtype: int64

# %%
df2['founded_at'].fillna(method='bfill',inplace=True)
df2
# Out:
#                                                permalink  \
# 0                                    /organization/-fame
# 1                                 /organization/-qounter
# 2                    /organization/-the-one-of-them-inc-
# 3                                  /organization/0-6-com
# 4                         /organization/004-technologies
# 5                       /organization/01games-technology
# 6                    /organization/0ndine-biomedical-inc
# 7                                   /organization/0xdata
# 8                                        /organization/1
# 9                              /organization/1-2-3-listo
# 10                                 /organization/1-4-all
# 11                        /organization/1-618-technology
# 12                           /organization/1-800-dentist
# 13                           /organization/1-800-doctors
# 14              /organization/1-800-publicrelations-inc-
# ...

# %%
df2.isnull().sum()
# Out:
# permalink        0
# name             0
# homepage_url     0
# category_list    0
# status           0
# country_code     0
# state_code       0
# region           0
# city             0
# founded_at       0
# dtype: int64

# %%
df3.isnull().sum()
# Out:
# permalink                  0
# funding_round_permalink    0
# funding_round_type         0
# funding_round_code         0
# funded_at                  0
# raised_amount_usd          0
# dtype: int64

# %%
dd=set(df3.company_permalink).difference(set(df2.permalink))
print(dd)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-151-5b05e3107b5a> in <module>
# ----> 1 dd=set(df3.company_permalink).difference(set(df2.permalink))
#       2 print(dd)
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5065             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5066                 return self[name]
# -> 5067             return object.__getattribute__(self, name)
#    5068
#    5069     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'company_permalink'

# %%
len(dd)
# Out:
# 9

# %%
dc=set(df2.permalink).difference(set(df3.company_permalink))
print(dc)
# Out:
# {'/organization/huizuche-com-æ\x83 ç§\x9fè½¦', '/organization/zengame-ç¦\x85æ¸¸ç§\x91æ\x9a\x80', '/organization/lawpã dã\xad', '/organization/e-cã\x9abica', '/organization/tipcat-interactive-æ²\x99è\x88\x9fä¿¡æ\x81¯ç§\x91æ\x9a\x80', '/organization/51wofang-æ\x97 å¿§æ\x88\x91æ\x88¿', '/organization/energystone-games-ç\x81µçÿ³æ¸¸æ\x88\x8f'}

# %%
len(dc)
# Out:
# 7

# %%
ds=set(dd).union(set(dc))
ds
# Out:
# {'/organization/51wofang-æ\x97 å¿§æ\x88\x91æ\x88¿',
#  '/organization/51wofang-æ\x97\xa0å¿§æ\x88\x91æ\x88¿',
#  '/organization/e-cã\x8abica',
#  '/organization/e-cã\x9abica',
#  '/organization/energystone-games-ç\x81µç\x9f³æ¸¸æ\x88\x8f',
#  '/organization/energystone-games-ç\x81µçÿ³æ¸¸æ\x88\x8f',
#  '/organization/huizuche-com-æ\x83 ç§\x9fè½¦',
#  '/organization/huizuche-com-æ\x83\xa0ç§ÿè½¦',
#  '/organization/lawpã dã\xad',
#  '/organization/lawpã\xa0dã\xad',
#  '/organization/magnet-tech-ç£\x81ç\x9f³ç§\x91æ\x8a\x80',
#  '/organization/tipcat-interactive-æ²\x99è\x88\x9fä¿¡æ\x81¯ç§\x91æ\x9a\x80',
#  '/organization/tipcat-interactive-æ²\x99è\x88ÿä¿¡æ\x81¯ç§\x91æ\x9a\x80',
#  '/organization/weiche-tech-å\x96\x82è½¦ç§\x91æ\x8a\x80',
#  '/organization/zengame-ç¦\x85æ¸¸ç§\x91æ\x8a\x80',
#  '/organization/zengame-ç¦\x85æ¸¸ç§\x91æ\x9a\x80'}

# %%
len(ds)
# Out:
# 16

# %%
df3['company_permalink']=df3['permalink']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2656             try:
# -> 2657                 return self._engine.get_loc(key)
#    2658             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'permalink'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-97-da2419deeef0> in <module>
# ----> 1 df3['company_permalink']=df3['permalink']
#
# ...

# %%
df2
# Out:
#                                                permalink  \
# 0                                    /organization/-fame
# 1                                 /organization/-qounter
# 2                    /organization/-the-one-of-them-inc-
# 3                                  /organization/0-6-com
# 4                         /organization/004-technologies
# 5                       /organization/01games-technology
# 6                    /organization/0ndine-biomedical-inc
# 7                                   /organization/0xdata
# 8                                        /organization/1
# 9                              /organization/1-2-3-listo
# 10                                 /organization/1-4-all
# 11                        /organization/1-618-technology
# 12                           /organization/1-800-dentist
# 13                           /organization/1-800-doctors
# 14              /organization/1-800-publicrelations-inc-
# ...

# %%
df3.rename({'company_permalink':'permalink'},axis=1,inplace=True)
df3
# Out:
#                                                 permalink  \
# 0                                     /organization/-fame
# 1                                  /organization/-qounter
# 2                                  /organization/-qounter
# 3                     /organization/-the-one-of-them-inc-
# 4                                   /organization/0-6-com
# 5                          /organization/004-technologies
# 6                        /organization/01games-technology
# 7                     /organization/0ndine-biomedical-inc
# 8                     /organization/0ndine-biomedical-inc
# 9                                    /organization/0xdata
# 10                                   /organization/0xdata
# 11                                   /organization/0xdata
# 12                                   /organization/0xdata
# 13                                        /organization/1
# 14                                        /organization/1
# ...

# %%
df2
# Out:
#                                                permalink  \
# 0                                    /organization/-fame
# 1                                 /organization/-qounter
# 2                    /organization/-the-one-of-them-inc-
# 3                                  /organization/0-6-com
# 4                         /organization/004-technologies
# 5                       /organization/01games-technology
# 6                    /organization/0ndine-biomedical-inc
# 7                                   /organization/0xdata
# 8                                        /organization/1
# 9                              /organization/1-2-3-listo
# 10                                 /organization/1-4-all
# 11                        /organization/1-618-technology
# 12                           /organization/1-800-dentist
# 13                           /organization/1-800-doctors
# 14              /organization/1-800-publicrelations-inc-
# ...

# %%
master=pd.merge(df3,df2,on='permalink',how='outer')
master
# Out:
#                                                 permalink  \
# 0                                     /organization/-fame
# 1                                  /organization/-qounter
# 2                                  /organization/-qounter
# 3                     /organization/-the-one-of-them-inc-
# 4                                   /organization/0-6-com
# 5                          /organization/004-technologies
# 6                        /organization/01games-technology
# 7                     /organization/0ndine-biomedical-inc
# 8                     /organization/0ndine-biomedical-inc
# 9                                    /organization/0xdata
# 10                                   /organization/0xdata
# 11                                   /organization/0xdata
# 12                                   /organization/0xdata
# 13                                        /organization/1
# 14                                        /organization/1
# ...

# %%
master.describe()
# Out:
#        raised_amount_usd
# count       1.149490e+05
# mean        1.019708e+07
# std         1.063257e+08
# min         0.000000e+00
# 25%         3.000000e+05
# 50%         1.599996e+06
# 75%         6.800000e+06
# max         2.127194e+10

# %%
master.to_csv("Master.csv")
