# %%
import pandas as pd
import numpy as np
df1=pd.read_csv("master.csv")
df1
# Out:
#                                                 permalink  \
# 0                                     /organization/-fame
# 1                                  /organization/-qounter
# 2                                  /organization/-qounter
# 3                     /organization/-the-one-of-them-inc-
# 4                                   /organization/0-6-com
# 5                          /organization/004-technologies
# 6                        /organization/01games-technology
# 7                     /organization/0ndine-biomedical-inc
# 8                     /organization/0ndine-biomedical-inc
# 9                                    /organization/0xdata
# 10                                   /organization/0xdata
# 11                                   /organization/0xdata
# 12                                   /organization/0xdata
# 13                                        /organization/1
# 14                                        /organization/1
# ...

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 114956 entries, 0 to 114955
# Data columns (total 15 columns):
# permalink                  114956 non-null object
# funding_round_permalink    114949 non-null object
# funding_round_type         114949 non-null object
# funding_round_code         114949 non-null object
# funded_at                  114949 non-null object
# raised_amount_usd          114949 non-null float64
# name                       114947 non-null object
# homepage_url               114947 non-null object
# category_list              114947 non-null object
# status                     114947 non-null object
# country_code               114947 non-null object
# state_code                 114947 non-null object
# region                     114947 non-null object
# city                       114947 non-null object
# founded_at                 114947 non-null object
# dtypes: float64(1), object(14)
# memory usage: 13.2+ MB

# %%
df1.isnull().sum()
# Out:
# permalink                  0
# funding_round_permalink    7
# funding_round_type         7
# funding_round_code         7
# funded_at                  7
# raised_amount_usd          7
# name                       9
# homepage_url               9
# category_list              9
# status                     9
# country_code               9
# state_code                 9
# region                     9
# city                       9
# founded_at                 9
# dtype: int64

# %%
df1.fillna(method='bfill',inplace=True)

# %%
df1.isnull().sum()
# Out:
# permalink                  0
# funding_round_permalink    7
# funding_round_type         7
# funding_round_code         7
# funded_at                  7
# raised_amount_usd          7
# name                       0
# homepage_url               0
# category_list              0
# status                     0
# country_code               0
# state_code                 0
# region                     0
# city                       0
# founded_at                 0
# dtype: int64

# %%
df1.fillna(method='ffill',inplace=True)

# %%
df1.isnull().sum()
# Out:
# permalink                  0
# funding_round_permalink    0
# funding_round_type         0
# funding_round_code         0
# funded_at                  0
# raised_amount_usd          0
# name                       0
# homepage_url               0
# category_list              0
# status                     0
# country_code               0
# state_code                 0
# region                     0
# city                       0
# founded_at                 0
# dtype: int64

# %%
a=df1.groupby('funding_round_type').mean()
a
# Out:
#                        raised_amount_usd
# funding_round_type
# angel                       1.990055e+06
# convertible_note            2.359123e+06
# debt_financing              1.669825e+07
# equity_crowdfunding         5.390505e+06
# grant                       4.295029e+06
# non_equity_assistance       6.617948e+06
# post_ipo_debt               1.687046e+08
# post_ipo_equity             8.132873e+07
# private_equity              6.420346e+07
# product_crowdfunding        1.672458e+06
# secondary_market            4.838805e+07
# seed                        2.388600e+06
# undisclosed                 1.233014e+07
# venture                     1.170373e+07

# %%
a=df1.groupby('funding_round_type').mean()
b=a.transpose()
b[['seed']]
# Out:
# funding_round_type          seed
# raised_amount_usd   2.388600e+06

# %%
a=df1.groupby('funding_round_type').mean()
b=a.transpose()
b[['venture']]
# Out:
# funding_round_type       venture
# raised_amount_usd   1.170373e+07

# %%
a=df1.groupby('funding_round_type').mean()
b=a.transpose()
b[['angel']]
# Out:
# funding_round_type         angel
# raised_amount_usd   1.990055e+06

# %%
a=df1.groupby('funding_round_type').mean()
b=a.transpose()
b[['private_equity']]
# Out:
# funding_round_type  private_equity
# raised_amount_usd     6.420346e+07

# %%
df1['country_code'].value_counts()
# Out:
# USA    77730
# GBR     6516
# CAN     3326
# CHN     3003
# IND     2480
# DEU     1900
# FRA     1820
# ISR     1742
# ESP     1326
# AUS      828
# NLD      794
# SGP      793
# BRA      773
# IRL      771
# RUS      759
# SWE      753
# JPN      699
# ITA      655
# KOR      599
# CHE      596
# CHL      499
# DNK      491
# FIN      485
# BEL      366
# ARG      352
# HKG      337
# TUR      302
# MEX      254
# NOR      238
# AUT      228
#        ...
# MOZ        3
# BAH        2
# NIC        2
# PSE        2
# ZMB        2
# BLZ        2
# MAF        2
# CIV        2
# KWT        2
# SOM        2
# KAZ        2
# HND        2
# OMN        1
# QAT        1
# JEY        1
# KNA        1
# UZB        1
# TGO        1
# BLM        1
# BRB        1
# GRD        1
# IRN        1
# BRN        1
# MNE        1
# SEN        1
# SYC        1
# DMA        1
# DZA        1
# GGY        1
# PRY        1
# Name: country_code, Length: 137, dtype: int64

# %%
a=df1.groupby('funding_round_type').mean()
a/1000000
# Out:
#                        raised_amount_usd
# funding_round_type
# angel                           1.990055
# convertible_note                2.359123
# debt_financing                 16.698252
# equity_crowdfunding             5.390505
# grant                           4.295029
# non_equity_assistance           6.617948
# post_ipo_debt                 168.704572
# post_ipo_equity                81.328733
# private_equity                 64.203457
# product_crowdfunding            1.672458
# secondary_market               48.388048
# seed                            2.388600
# undisclosed                    12.330139
# venture                        11.703734
