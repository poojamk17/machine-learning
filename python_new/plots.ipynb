# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import math as m
x=[1,2,3,4,5,6]
y=[3,4,2,9,10,12]

# %%
plt.figure(figsize=(8,1))
plt.plot(x,y)

# %%
plt.plot(x,y,'r')

# %%
plt.plot(x,y,'r')
plt.xlabel('age')
plt.ylabel('wt')
plt.title('GRAPH')
# plt.show()
# Out:
# Text(0.5, 1.0, 'GRAPH')

# %%
plt.plot(x,y,'r')
plt.xlabel('age')
plt.ylabel('wt')
plt.title('GRAPH')
plt.show()

# %%
plt.plot(x,y,'g')
plt.xlabel('age')
plt.ylabel('wt')
plt.title('GRAPH')
# plt.show()
# Out:
# Text(0.5, 1.0, 'GRAPH')

# %%
plt.plot(x,y,'y')
plt.xlabel('age')
plt.ylabel('wt')
plt.title('GRAPH')
plt.show()

# %%
plt.plot(x,y)
plt.xlabel('age')
plt.ylabel('wt')
plt.title('GRAPH')
# plt.show()
# Out:
# Text(0.5, 1.0, 'GRAPH')

# %%
x=np.arange(10)
y=x**2
plt.plot(x,y)
plt.xlabel('x axis')
plt.ylabel('y axis')
plt.title('GRAPH')
plt.show()

# %%
x=np.arange(10)
y=m.e**x
plt.plot(x,y)
plt.xlabel('x axis')
plt.ylabel('y axis')
plt.title('GRAPH')
plt.show()

# %%
y=np.e**(-x)
plt.plot(x,y)
plt.xlabel('x axis')
plt.ylabel('y axis')
plt.title('GRAPH')
plt.show()

# %%
x=np.arange(10)
y=np.e**(-x)
plt.plot(x,y)
plt.xlabel('x axis')
plt.ylabel('y axis')
plt.title('GRAPH')
plt.show()

# %%
y=m.e**(-x)
plt.plot(x,y)
plt.xlabel('x axis')
plt.ylabel('y axis')
plt.title('GRAPH')
plt.show()

# %%
y=np.log(x)
plt.plot(x,y)
plt.xlabel('x axis')
plt.ylabel('y axis')
plt.title('GRAPH')
plt.show()
# Out:
# C:\Users\User\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: RuntimeWarning: divide by zero encountered in log
#   """Entry point for launching an IPython kernel.

# %%
y=3*x**2
plt.plot(x,y)
plt.xlabel('x axis')
plt.ylabel('y axis')
plt.title('GRAPH')
plt.show()

# %%
x=4*y**2
plt.plot(x,y)
plt.xlabel('x axis')
plt.ylabel('y axis')
plt.title('GRAPH')
plt.show()

# %%
y=x**(1/3)
plt.plot(x,y,'o')
plt.xlabel('x axis')
plt.ylabel('y axis')
plt.title('GRAPH')
plt.show()

# %%
x=[1,2,3,4,5,6]
y=[3,4,2,9,10,12]
plt.scatter(x,y)

# %%
plt.bar(x,y,)
plt.show()

# %%
plt.plot(x,y,'o')

# %%
plt.plot(x,y,'p')

# %%
plt.plot(x,y,'v')

# %%
x=[3,2,4]
y=[0,0.1,0.2]
plt.pie(x)
plt.show()

# %%
x=[3,2,4]
y=[0,0.1,0.2]
plt.pie(x,y)
plt.show()

# %%
x=[3,2,4]
y=[0,10,20]
plt.pie(x,y)
plt.show()

# %%
x=[3,2,4,5,6]
y=[0,10,20,30,40]
plt.pie(x)
plt.show()

# %%
x=[3,2,4,5,6]
y=[0,10,20,30,40]
plt.pie(x,y)
plt.show()

# %%
x=[3,2,4]
y=[0,0.1,0.2]
z=[0,1,2]
plt.pie(x,y,z,'b','pooja')
plt.show()

# %%
x=[1,2,3,4,5,6]
y=[3,4,2,9,10,12]
x1=[10,20,30,0,1]
y1=[30,20,20,11,1]
plt.subplot(1,2,1)
plt.plot(x,y)
plt.subplot(1,2,2)
plt.plot(x1,y1)
plt.show()

# %%
x=[1,2,3,4,5,6]
y=[3,4,2,9,10,12]
x1=[10,20,30,0,1]
y1=[30,20,20,11,1]
 
plt.plot(x,y)
plt.subplot(4,2,2)
plt.plot(x1,y1,'r')
plt.subplot(4,2,3)
plt.plot(x1,y1,'y')
plt.subplot(4,2,4)
plt.plot(x,y,'g')
plt.subplot(4,2,5)
plt.plot(x1,y1,'c')
plt.subplot(4,2,6)
plt.plot(x1,y1,'b')
plt.subplot(4,2,7)
plt.plot(x1,y1,'d')
plt.show()

# %%
x=[1,2,3,4,5,6]
y=[3,4,2,9,10,12]
x1=[10,20,30,0,1]
y1=[30,20,20,11,1]
plt.subplot(2,2,1)
plt.plot(x,y)
plt.subplot(2,2,2)
plt.plot(x1,y1,'o')
plt.subplot(2,2,3)
plt.plot(x1,y1,'v')
plt.subplot(2,2,4)
plt.plot(x1,y1,'r')
plt.show()

# %%
a=np.array([1,2,3,4])
b=np.array([10,20,30,40])
plt.plot(a,b,'r')
plt.show()

# %%
a=[1,2,3]
b=a*a
plt.plot(a,b)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-33-df94646fa546> in <module>
#       1 a=[1,2,3]
# ----> 2 b=a*a
#       3 plt.plot(a,b)
#
# TypeError: can't multiply sequence by non-int of type 'list'

# %%
a=[1,2,3]
b=a*2
plt.plot(a,b)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-41-0cc8af63674f> in <module>
#       1 a=[1,2,3]
#       2 b=a*2
# ----> 3 plt.plot(a,b)
#
# ~\Anaconda3\lib\site-packages\matplotlib\pyplot.py in plot(scalex, scaley, data, *args, **kwargs)
#    2787     return gca().plot(
#    2788         *args, scalex=scalex, scaley=scaley, **({"data": data} if data
# -> 2789         is not None else {}), **kwargs)
#    2790
#    2791
#
# ~\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py in plot(self, scalex, scaley, data, *args, **kwargs)
#    1664         """
#    1665         kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D._alias_map)
# -> 1666         lines = [*self._get_lines(*args, data=data, **kwargs)]
#    1667         for line in lines:
#    1668             self.add_line(line)
#
# ...

# %%
a=np.arange(10)
b=np.sin(100*a)
plt.plot(a,b)

# %%
0
# Out:
#                   model   mpg  cyl   disp   hp  drat     wt   qsec  vs  am  \
# 0             Mazda RX4  21.0    6  160.0  110  3.90  2.620  16.46   0   1
# 1         Mazda RX4 Wag  21.0    6  160.0  110  3.90  2.875  17.02   0   1
# 2            Datsun 710  22.8    4  108.0   93  3.85  2.320  18.61   1   1
# 3        Hornet 4 Drive  21.4    6  258.0  110  3.08  3.215  19.44   1   0
# 4     Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.02   0   0
# 5               Valiant  18.1    6  225.0  105  2.76  3.460  20.22   1   0
# 6            Duster 360  14.3    8  360.0  245  3.21  3.570  15.84   0   0
# 7             Merc 240D  24.4    4  146.7   62  3.69  3.190  20.00   1   0
# 8              Merc 230  22.8    4  140.8   95  3.92  3.150  22.90   1   0
# 9              Merc 280  19.2    6  167.6  123  3.92  3.440  18.30   1   0
# 10            Merc 280C  17.8    6  167.6  123  3.92  3.440  18.90   1   0
# ...

# %%
df.plot()

# %%
df['mpg'].plot()

# %%
plt.scatter(df['mpg'],df['cyl'])

# %%
df1=df.loc[:,['mpg','hp','wt']]
df1.plot(kind='bar')

# %%
df1=df.loc[:,['mpg','hp','wt']]
df1.plot(kind='barh')

# %%
fig=plt.figure()
axis=fig.add_axes([0.1,0.1,0.9,0.9])
axis.plot(x,y)

# %%
fig=plt.figure()
axis=fig.add_axes([0.5,0.6,0.7,0.5])
axis.plot(x,y)
axis.set_xlabel('x axis')
axis.set_ylabel('y axis')
# Out:
# Text(0, 0.5, 'y axis')

# %%
fig=plt.figure()
axis=fig.add_axes([0.6,0.6,0.5,0.5])
axis.plot(x,y)
axis.set_xlabel('x axis')
axis.set_ylabel('y axis')
# Out:
# Text(0, 0.5, 'y axis')

# %%
fig=plt.figure()

axis=fig.add_axes([0.1,0.1,1,1])
axis.plot(x,y)
axis.set_xlabel('x axis')
axis.set_ylabel('y axis')
# Out:
# Text(0, 0.5, 'y axis')

# %%
x=np.arange(10)
y=x**2
fig=plt.figure()
axes1=fig.add_axes([0.1,0.1,1,1])
axes1.plot(x,y)
axes2=fig.add_axes([0.4,0.4,0.4,0.4])
axes2.plot(x,y)
axes1.set_xlabel('x axis')
axes1.set_ylabel('y axis')
# Out:
# Text(0, 0.5, 'y axis')

# %%
x=np.arange(10)
y=x**2
fig=plt.figure()
axes1=fig.add_axes([0.1,0.1,1,1])
axes1.plot(x,y)
axes2=fig.add_axes([0.2,0.5,0.4,0.3])
axes2.plot(x,y)
axes1.set_xlabel('x axis')
axes1.set_ylabel('y axis')
# Out:
# Text(0, 0.5, 'y axis')

# %%
x=np.arange(10)
y=x**2
fig=plt.figure()
axes1=fig.add_axes([0.2,0.2,0.2,0.2])
axes1.plot(x,y)
axes2=fig.add_axes([0.2,0.5,0.4,0.2])
axes2.plot(x,y)
axes1.set_xlabel('x axis')
axes1.set_ylabel('y axis')
# Out:
# Text(0, 0.5, 'y axis')

# %%
x=np.arange(10)
y=x**2
fig=plt.figure()
axes1=fig.add_axes([0.1,0.1,0.6,0.6])
axes1.plot(x,y)
axes2=fig.add_axes([0.8,0.1,0.6,0.6])
axes2.plot(x,y)
axes1.set_xlabel('x axis')
axes1.set_ylabel('y axis')
# Out:
# Text(0, 0.5, 'y axis')

# %%
plt.figure(figsize=(8,16))
x=np.arange(10)
y=x**2
fig=plt.figure()
axes1=fig.add_axes([0.1,0.1,0.6,0.6])
axes1.plot(x,y)
axes2=fig.add_axes([0.8,0.1,0.6,0.6])
axes2.plot(x,y)
axes1.set_xlabel('x axis')
axes1.set_ylabel('y axis')
# Out:
# Text(0, 0.5, 'y axis')

# %%
plt.figure(figsize=(8,12))
x=np.arange(10)
y=x**2
fig=plt.figure()
axes1=fig.add_axes([0.2,0.2,0.2,0.2])
axes1.plot(x,y)
axes2=fig.add_axes([0.2,0.5,0.4,0.2])
axes2.plot(x,y)
axes1.set_xlabel('x axis')
axes1.set_ylabel('y axis')
# Out:
# Text(0, 0.5, 'y axis')

# %%
x=np.arange(10)
y=4*(x**2)
fig=plt.figure()
ax=fig.add_axes([0,0,0.5,1])
ax.plot(x,y)
ax.set_xlabel('x-axis')
ax.set_ylabel('y-axis')
ax.set_title('graph')
ax.set_xticks([1,3,5,7,9])
ax.set_xticklabels(['first','third','fifth','seventh','ninth'],rotation=60,fontsize=20)
# Out:
# [Text(0, 0, 'first'),
#  Text(0, 0, 'third'),
#  Text(0, 0, 'fifth'),
#  Text(0, 0, 'seventh'),
#  Text(0, 0, 'ninth')]
