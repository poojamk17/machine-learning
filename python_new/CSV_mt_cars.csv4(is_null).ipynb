# %%
import numpy as np
import pandas as pd
df=pd.read_csv('mt_cars.csv')
df
# Out:
#                   model   mpg  cyl   disp     hp  drat     wt   qsec  vs  am  \
# 0             Mazda RX4  21.0    6  160.0  110.0  3.90  2.620  16.46   0   1
# 1         Mazda RX4 Wag  21.0    6  160.0  110.0  3.90  2.875  17.02   0   1
# 2            Datsun 710  22.8    4  108.0   93.0  3.85  2.320  18.61   1   1
# 3        Hornet 4 Drive  21.4    6  258.0  110.0  3.08  3.215  19.44   1   0
# 4     Hornet Sportabout   NaN    8  360.0  175.0  3.15  3.440  17.02   0   0
# 5               Valiant  18.1    6  225.0  105.0  2.76  3.460  20.22   1   0
# 6            Duster 360  14.3    8  360.0  245.0   NaN  3.570  15.84   0   0
# 7             Merc 240D  24.4    4  146.7   62.0  3.69  3.190  20.00   1   0
# 8              Merc 230  22.8    4  140.8   95.0   NaN  3.150  22.90   1   0
# 9              Merc 280  19.2    6    NaN  123.0  3.92  3.440  18.30   1   0
# 10            Merc 280C  17.8    6  167.6    NaN  3.92  3.440  18.90   1   0
# ...

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.shape
# Out:
# (32, 12)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32 entries, 0 to 31
# Data columns (total 12 columns):
# model    32 non-null object
# mpg      27 non-null float64
# cyl      32 non-null int64
# disp     24 non-null float64
# hp       25 non-null float64
# drat     26 non-null float64
# wt       28 non-null float64
# qsec     31 non-null float64
# vs       32 non-null int64
# am       32 non-null int64
# gear     32 non-null int64
# carb     32 non-null int64
# dtypes: float64(6), int64(5), object(1)
# memory usage: 3.1+ KB

# %%
df.isnull().sum()
# Out:
# model    0
# mpg      5
# cyl      0
# disp     8
# hp       7
# drat     6
# wt       4
# qsec     1
# vs       0
# am       0
# gear     0
# carb     0
# dtype: int64

# %%
df.isnull().sum(axis=1)
# Out:
# 0     0
# 1     0
# 2     0
# 3     0
# 4     1
# 5     0
# 6     1
# 7     0
# 8     1
# 9     1
# 10    1
# 11    1
# 12    2
# 13    2
# 14    4
# 15    0
# 16    2
# 17    0
# 18    1
# 19    3
# 20    1
# 21    1
# 22    1
# 23    1
# 24    0
# 25    0
# 26    1
# 27    0
# 28    3
# 29    1
# 30    0
# 31    2
# dtype: int64

# %%
df['am'].value_counts()
# Out:
# 0    19
# 1    13
# Name: am, dtype: int64

# %%
df.isnull().all()
# Out:
# model    False
# mpg      False
# cyl      False
# disp     False
# hp       False
# drat     False
# wt       False
# qsec     False
# vs       False
# am       False
# gear     False
# carb     False
# dtype: bool

# %%
df.isnull().any()
# Out:
# model    False
# mpg       True
# cyl      False
# disp      True
# hp        True
# drat      True
# wt        True
# qsec      True
# vs       False
# am       False
# gear     False
# carb     False
# dtype: bool

# %%
round(100*df.isnull().sum()/len(df),2)
# Out:
# model     0.00
# mpg      15.62
# cyl       0.00
# disp     25.00
# hp       21.88
# drat     18.75
# wt       12.50
# qsec      3.12
# vs        0.00
# am        0.00
# gear      0.00
# carb      0.00
# dtype: float64

# %%
df1=df.drop('disp',axis=1) #disp col is remove so 11
df1.shape
# Out:
# (32, 11)

# %%
df.drop('disp',axis=1,inplace=True)

# %%
df
# Out:
#                   model   mpg  cyl     hp  drat     wt   qsec  vs  am  gear  \
# 0             Mazda RX4  21.0    6  110.0  3.90  2.620  16.46   0   1     4
# 1         Mazda RX4 Wag  21.0    6  110.0  3.90  2.875  17.02   0   1     4
# 2            Datsun 710  22.8    4   93.0  3.85  2.320  18.61   1   1     4
# 3        Hornet 4 Drive  21.4    6  110.0  3.08  3.215  19.44   1   0     3
# 4     Hornet Sportabout   NaN    8  175.0  3.15  3.440  17.02   0   0     3
# 5               Valiant  18.1    6  105.0  2.76  3.460  20.22   1   0     3
# 6            Duster 360  14.3    8  245.0   NaN  3.570  15.84   0   0     3
# 7             Merc 240D  24.4    4   62.0  3.69  3.190  20.00   1   0     4
# 8              Merc 230  22.8    4   95.0   NaN  3.150  22.90   1   0     4
# 9              Merc 280  19.2    6  123.0  3.92  3.440  18.30   1   0     4
# 10            Merc 280C  17.8    6    NaN  3.92  3.440  18.90   1   0     4
# ...

# %%
df.isnull().sum(axis=1)>2
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14     True
# 15    False
# 16    False
# 17    False
# 18    False
# 19     True
# 20    False
# 21    False
# 22    False
# 23    False
# 24    False
# 25    False
# 26    False
# 27    False
# 28    False
# 29    False
# 30    False
# 31    False
# dtype: bool

# %%
df[df.isnull().sum(axis=1)>2] #row wise nan more than 2
# Out:
#                  model   mpg  cyl  hp  drat     wt   qsec  vs  am  gear  carb
# 14  Cadillac Fleetwood  10.4    8 NaN   NaN    NaN  17.98   0   0     3     4
# 19      Toyota Corolla  33.9    4 NaN   NaN  1.835    NaN   1   1     4     1

# %%
round(100*len(df[df.isnull().sum(axis=1)>2])/len(df),2)
# Out:
# 6.25

# %%
np.isnan(df['hp']).sum()
# Out:
# 7

# %%
df1=df[~np.isnan(df['hp'])] # remove rows with nan value of age 
df1
# Out:
#                   model   mpg  cyl     hp  drat     wt   qsec  vs  am  gear  \
# 0             Mazda RX4  21.0    6  110.0  3.90  2.620  16.46   0   1     4
# 1         Mazda RX4 Wag  21.0    6  110.0  3.90  2.875  17.02   0   1     4
# 2            Datsun 710  22.8    4   93.0  3.85  2.320  18.61   1   1     4
# 3        Hornet 4 Drive  21.4    6  110.0  3.08  3.215  19.44   1   0     3
# 4     Hornet Sportabout   NaN    8  175.0  3.15  3.440  17.02   0   0     3
# 5               Valiant  18.1    6  105.0  2.76  3.460  20.22   1   0     3
# 6            Duster 360  14.3    8  245.0   NaN  3.570  15.84   0   0     3
# 7             Merc 240D  24.4    4   62.0  3.69  3.190  20.00   1   0     4
# 8              Merc 230  22.8    4   95.0   NaN  3.150  22.90   1   0     4
# 9              Merc 280  19.2    6  123.0  3.92  3.440  18.30   1   0     4
# 12           Merc 450SL   NaN    8  180.0   NaN  3.730  17.60   0   0     3
# ...

# %%
df1.shape #some rows are deleted
# Out:
# (25, 11)

# %%
df.drop(df.index[14],inplace=True)

# %%
df.drop(df.index[19],inplace=True)

# %%
df
# Out:
#                   model   mpg  cyl     hp  drat     wt   qsec  vs  am  gear  \
# 0             Mazda RX4  21.0    6  110.0  3.90  2.620  16.46   0   1     4
# 1         Mazda RX4 Wag  21.0    6  110.0  3.90  2.875  17.02   0   1     4
# 2            Datsun 710  22.8    4   93.0  3.85  2.320  18.61   1   1     4
# 3        Hornet 4 Drive  21.4    6  110.0  3.08  3.215  19.44   1   0     3
# 4     Hornet Sportabout   NaN    8  175.0  3.15  3.440  17.02   0   0     3
# 5               Valiant  18.1    6  105.0  2.76  3.460  20.22   1   0     3
# 6            Duster 360  14.3    8  245.0   NaN  3.570  15.84   0   0     3
# 7             Merc 240D  24.4    4   62.0  3.69  3.190  20.00   1   0     4
# 8              Merc 230  22.8    4   95.0   NaN  3.150  22.90   1   0     4
# 9              Merc 280  19.2    6  123.0  3.92  3.440  18.30   1   0     4
# 10            Merc 280C  17.8    6    NaN  3.92  3.440  18.90   1   0     4
# ...

# %%
df.fillna(value='NULL_VALUE')
# Out:
#                   model         mpg  cyl          hp        drat          wt  \
# 0             Mazda RX4          21    6         110         3.9        2.62
# 1         Mazda RX4 Wag          21    6         110         3.9       2.875
# 2            Datsun 710        22.8    4          93        3.85        2.32
# 3        Hornet 4 Drive        21.4    6         110        3.08       3.215
# 4     Hornet Sportabout  NULL_VALUE    8         175        3.15        3.44
# 5               Valiant        18.1    6         105        2.76        3.46
# 6            Duster 360        14.3    8         245  NULL_VALUE        3.57
# 7             Merc 240D        24.4    4          62        3.69        3.19
# 8              Merc 230        22.8    4          95  NULL_VALUE        3.15
# 9              Merc 280        19.2    6         123        3.92        3.44
# 10            Merc 280C        17.8    6  NULL_VALUE        3.92        3.44
# ...

# %%
df['hp'].fillna(value=df['hp'].mean(),inplace=True) #144.56 is mean

# %%
df['mpg'].fillna(method='bfill',inplace=True)

# %%
df['drat'].fillna(value=df['drat'].mean(),inplace=True)

# %%
df['wt'].fillna(value=df['wt'].mean(),inplace=True)

# %%
df
# Out:
#                   model   mpg  cyl      hp      drat       wt   qsec  vs  am  \
# 0             Mazda RX4  21.0    6  110.00  3.900000  2.62000  16.46   0   1
# 1         Mazda RX4 Wag  21.0    6  110.00  3.900000  2.87500  17.02   0   1
# 2            Datsun 710  22.8    4   93.00  3.850000  2.32000  18.61   1   1
# 3        Hornet 4 Drive  21.4    6  110.00  3.080000  3.21500  19.44   1   0
# 4     Hornet Sportabout  18.1    8  175.00  3.150000  3.44000  17.02   0   0
# 5               Valiant  18.1    6  105.00  2.760000  3.46000  20.22   1   0
# 6            Duster 360  14.3    8  245.00  3.601154  3.57000  15.84   0   0
# 7             Merc 240D  24.4    4   62.00  3.690000  3.19000  20.00   1   0
# 8              Merc 230  22.8    4   95.00  3.601154  3.15000  22.90   1   0
# 9              Merc 280  19.2    6  123.00  3.920000  3.44000  18.30   1   0
# 10            Merc 280C  17.8    6  144.56  3.920000  3.44000  18.90   1   0
# ...

# %%
df.drop(df.index[[12,13]]) #for simultantanous 2 row droping
# Out:
#                   model   mpg  cyl      hp      drat       wt   qsec  vs  am  \
# 0             Mazda RX4  21.0    6  110.00  3.900000  2.62000  16.46   0   1
# 1         Mazda RX4 Wag  21.0    6  110.00  3.900000  2.87500  17.02   0   1
# 2            Datsun 710  22.8    4   93.00  3.850000  2.32000  18.61   1   1
# 3        Hornet 4 Drive  21.4    6  110.00  3.080000  3.21500  19.44   1   0
# 4     Hornet Sportabout  18.1    8  175.00  3.150000  3.44000  17.02   0   0
# 5               Valiant  18.1    6  105.00  2.760000  3.46000  20.22   1   0
# 6            Duster 360  14.3    8  245.00  3.601154  3.57000  15.84   0   0
# 7             Merc 240D  24.4    4   62.00  3.690000  3.19000  20.00   1   0
# 8              Merc 230  22.8    4   95.00  3.601154  3.15000  22.90   1   0
# 9              Merc 280  19.2    6  123.00  3.920000  3.44000  18.30   1   0
# 10            Merc 280C  17.8    6  144.56  3.920000  3.44000  18.90   1   0
# ...

# %%
df.shape
# Out:
# (30, 11)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 30 entries, 0 to 31
# Data columns (total 11 columns):
# model    30 non-null object
# mpg      30 non-null float64
# cyl      30 non-null int64
# hp       30 non-null float64
# drat     30 non-null float64
# wt       30 non-null float64
# qsec     30 non-null float64
# vs       30 non-null int64
# am       30 non-null int64
# gear     30 non-null int64
# carb     30 non-null int64
# dtypes: float64(5), int64(5), object(1)
# memory usage: 4.1+ KB

# %%
df[df['cyl'==6]]['wt']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2656             try:
# -> 2657                 return self._engine.get_loc(key)
#    2658             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: False
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-59-03ace50aa8ae> in <module>
# ----> 1 df[df['cyl'==6]]['wt']
#
# ...
