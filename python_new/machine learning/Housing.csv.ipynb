# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
# Out:
# C:\Users\User\Anaconda3\lib\importlib\_bootstrap.py:219: RuntimeWarning: numpy.ufunc size changed, may indicate binary incompatibility. Expected 192 from C header, got 216 from PyObject
#   return f(*args, **kwds)
# C:\Users\User\Anaconda3\lib\importlib\_bootstrap.py:219: RuntimeWarning: numpy.ufunc size changed, may indicate binary incompatibility. Expected 192 from C header, got 216 from PyObject
#   return f(*args, **kwds)
# C:\Users\User\Anaconda3\lib\importlib\_bootstrap.py:219: RuntimeWarning: numpy.ufunc size changed, may indicate binary incompatibility. Expected 192 from C header, got 216 from PyObject
#   return f(*args, **kwds)
# C:\Users\User\Anaconda3\lib\importlib\_bootstrap.py:219: RuntimeWarning: numpy.ufunc size changed, may indicate binary incompatibility. Expected 192 from C header, got 216 from PyObject
#   return f(*args, **kwds)

# %%
df1=pd.read_csv('Housing.csv')
df1
# Out:
#         price   area  bedrooms  bathrooms  stories mainroad guestroom  \
# 0    13300000   7420         4          2        3      yes        no
# 1    12250000   8960         4          4        4      yes        no
# 2    12250000   9960         3          2        2      yes        no
# 3    12215000   7500         4          2        2      yes        no
# 4    11410000   7420         4          1        2      yes       yes
# 5    10850000   7500         3          3        1      yes        no
# 6    10150000   8580         4          3        4      yes        no
# 7    10150000  16200         5          3        2      yes        no
# 8     9870000   8100         4          1        2      yes       yes
# 9     9800000   5750         3          2        4      yes       yes
# 10    9800000  13200         3          1        2      yes        no
# 11    9681000   6000         4          3        2      yes       yes
# ...

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 545 entries, 0 to 544
# Data columns (total 13 columns):
# price               545 non-null int64
# area                545 non-null int64
# bedrooms            545 non-null int64
# bathrooms           545 non-null int64
# stories             545 non-null int64
# mainroad            545 non-null object
# guestroom           545 non-null object
# basement            545 non-null object
# hotwaterheating     545 non-null object
# airconditioning     545 non-null object
# parking             545 non-null int64
# prefarea            545 non-null object
# furnishingstatus    545 non-null object
# dtypes: int64(6), object(7)
# memory usage: 55.4+ KB

# %%
df1.isnull().sum()
# Out:
# price               0
# area                0
# bedrooms            0
# bathrooms           0
# stories             0
# mainroad            0
# guestroom           0
# basement            0
# hotwaterheating     0
# airconditioning     0
# parking             0
# prefarea            0
# furnishingstatus    0
# dtype: int64

# %%
df1.describe()
# Out:
#               price          area    bedrooms   bathrooms     stories  \
# count  5.450000e+02    545.000000  545.000000  545.000000  545.000000
# mean   4.766729e+06   5150.541284    2.965138    1.286239    1.805505
# std    1.870440e+06   2170.141023    0.738064    0.502470    0.867492
# min    1.750000e+06   1650.000000    1.000000    1.000000    1.000000
# 25%    3.430000e+06   3600.000000    2.000000    1.000000    1.000000
# 50%    4.340000e+06   4600.000000    3.000000    1.000000    2.000000
# 75%    5.740000e+06   6360.000000    3.000000    2.000000    2.000000
# max    1.330000e+07  16200.000000    6.000000    4.000000    4.000000
#
#           parking
# count  545.000000
# mean     0.693578
# std      0.861586
# min      0.000000
# 25%      0.000000
# 50%      0.000000
# 75%      1.000000
# max      3.000000

# %%
df1.shape
# Out:
# (545, 13)

# %%
df1.head()
# Out:
#       price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0  13300000  7420         4          2        3      yes        no       no
# 1  12250000  8960         4          4        4      yes        no       no
# 2  12250000  9960         3          2        2      yes        no      yes
# 3  12215000  7500         4          2        2      yes        no      yes
# 4  11410000  7420         4          1        2      yes       yes      yes
#
#   hotwaterheating airconditioning  parking prefarea furnishingstatus
# 0              no             yes        2      yes        furnished
# 1              no             yes        3       no        furnished
# 2              no              no        2      yes   semi-furnished
# 3              no             yes        3      yes        furnished
# 4              no             yes        2       no        furnished

# %%
df1.groupby('mainroad')[['price']].mean() ### it matters for to predict
# Out:
#                  price
# mainroad
# no        3.398905e+06
# yes       4.991777e+06

# %%
df1.groupby('guestroom')[['price']].mean() ### it matters for to predict
# Out:
#                   price
# guestroom
# 0          4.544546e+06
# 1          5.792897e+06

# %%
df1.groupby('basement')[['price']].mean() ### it matters for to predict
# Out:
#                  price
# basement
# no        4.509966e+06
# yes       5.242615e+06

# %%
df1.groupby('hotwaterheating')[['price']].mean() ### it matters for to predict
# Out:
#                         price
# hotwaterheating
# no               4.728593e+06
# yes              5.559960e+06

# %%
df1.groupby('airconditioning')[['price']].mean() ### it matters for to predict so we need to conver into numeric
# Out:
#                         price
# airconditioning
# no               4.191940e+06
# yes              6.013221e+06

# %%
df1.groupby('prefarea')[['price']].mean() ### it matters for to predict
# Out:
#                  price
# prefarea
# no        4.425299e+06
# yes       5.879046e+06

# %%
df1.groupby('furnishingstatus')[['price']].mean()
# Out:
#                          price
# furnishingstatus
# furnished         5.495696e+06
# semi-furnished    4.907524e+06
# unfurnished       4.013831e+06

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le=LabelEncoder()

# %%
df1.mainroad=le.fit_transform(df1['mainroad'])

# %%
df1.head()
# Out:
#       price  area  bedrooms  bathrooms  stories  mainroad guestroom basement  \
# 0  13300000  7420         4          2        3         1        no       no
# 1  12250000  8960         4          4        4         1        no       no
# 2  12250000  9960         3          2        2         1        no      yes
# 3  12215000  7500         4          2        2         1        no      yes
# 4  11410000  7420         4          1        2         1       yes      yes
#
#   hotwaterheating airconditioning  parking prefarea furnishingstatus
# 0              no             yes        2      yes        furnished
# 1              no             yes        3       no        furnished
# 2              no              no        2      yes   semi-furnished
# 3              no             yes        3      yes        furnished
# 4              no             yes        2       no        furnished

# %%
df1.guestroom=le.fit_transform(df1['guestroom'])

# %%
df1.head()
# Out:
#       price  area  bedrooms  bathrooms  stories  mainroad  guestroom basement  \
# 0  13300000  7420         4          2        3         1          0       no
# 1  12250000  8960         4          4        4         1          0       no
# 2  12250000  9960         3          2        2         1          0      yes
# 3  12215000  7500         4          2        2         1          0      yes
# 4  11410000  7420         4          1        2         1          1      yes
#
#   hotwaterheating airconditioning  parking prefarea furnishingstatus
# 0              no             yes        2      yes        furnished
# 1              no             yes        3       no        furnished
# 2              no              no        2      yes   semi-furnished
# 3              no             yes        3      yes        furnished
# 4              no             yes        2       no        furnished

# %%
df1.basement=le.fit_transform(df1['basement'])

# %%
df1.hotwaterheating=le.fit_transform(df1['hotwaterheating'])

# %%
df1.airconditioning=le.fit_transform(df1['airconditioning'])

# %%
df1.prefarea=le.fit_transform(df1['prefarea'])

# %%
df1.furnishingstatus=le.fit_transform(df1['furnishingstatus'])

# %%
df1.head(10)
# Out:
#       price   area  bedrooms  bathrooms  stories  mainroad  guestroom  \
# 0  13300000   7420         4          2        3         1          0
# 1  12250000   8960         4          4        4         1          0
# 2  12250000   9960         3          2        2         1          0
# 3  12215000   7500         4          2        2         1          0
# 4  11410000   7420         4          1        2         1          1
# 5  10850000   7500         3          3        1         1          0
# 6  10150000   8580         4          3        4         1          0
# 7  10150000  16200         5          3        2         1          0
# 8   9870000   8100         4          1        2         1          1
# 9   9800000   5750         3          2        4         1          1
#
#    basement  hotwaterheating  airconditioning  parking  prefarea  \
# 0         0                0                1        2         1
# ...

# %%
plt.figure(figsize=(10,5))
sns.heatmap(df1.corr(),annot=True) ##furnishing is less corelated with price so we can drop it

# %%
sns.pairplot(df1)

# %%
sns.distplot(df1['price'])

# %%
X=df1.drop(['price','furnishingstatus','guestroom','basement','hotwaterheating'],axis=1)
X
# Out:
#       area  bedrooms  bathrooms  stories  mainroad  airconditioning  parking  \
# 0     7420         4          2        3         1                1        2
# 1     8960         4          4        4         1                1        3
# 2     9960         3          2        2         1                0        2
# 3     7500         4          2        2         1                1        3
# 4     7420         4          1        2         1                1        2
# 5     7500         3          3        1         1                1        2
# 6     8580         4          3        4         1                1        2
# 7    16200         5          3        2         1                0        0
# 8     8100         4          1        2         1                1        2
# 9     5750         3          2        4         1                1        1
# 10   13200         3          1        2         1                1        2
# ...

# %%
y=df1['price']
y
# Out:
# 0      13300000
# 1      12250000
# 2      12250000
# 3      12215000
# 4      11410000
# 5      10850000
# 6      10150000
# 7      10150000
# 8       9870000
# 9       9800000
# 10      9800000
# 11      9681000
# 12      9310000
# 13      9240000
# 14      9240000
# 15      9100000
# 16      9100000
# 17      8960000
# 18      8890000
# 19      8855000
# 20      8750000
# 21      8680000
# 22      8645000
# 23      8645000
# 24      8575000
# 25      8540000
# 26      8463000
# 27      8400000
# 28      8400000
# 29      8400000
#          ...
# 515     2450000
# 516     2450000
# 517     2450000
# 518     2450000
# 519     2450000
# 520     2450000
# 521     2408000
# 522     2380000
# 523     2380000
# 524     2380000
# 525     2345000
# 526     2310000
# 527     2275000
# 528     2275000
# 529     2275000
# 530     2240000
# 531     2233000
# 532     2135000
# 533     2100000
# 534     2100000
# 535     2100000
# 536     1960000
# 537     1890000
# 538     1890000
# ...

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.3,random_state=1)

# %%
from sklearn.linear_model import LinearRegression

# %%
lireg=LinearRegression()

# %%
lireg.fit(X_train,y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
lireg.intercept_
# Out:
# -142444.26113675255

# %%
lireg.coef_
# Out:
# array([2.37540904e+02, 1.05275932e+05, 1.17226760e+06, 4.27476081e+05,
#        5.96419342e+05, 6.21735388e+05, 3.16114602e+05, 6.79349008e+05])

# %%
y_pred=lireg.predict(X_test)

# %%
y_pred_train=lireg.predict(X_train)

# %%
from sklearn import metrics

# %%
metrics.r2_score(y_train,y_pred_train)
# Out:
# 0.6343516618793819

# %%
metrics.r2_score(y_test,y_pred)
# Out:
# 0.6548370479263823

# %%
print('MAE',metrics.mean_absolute_error(y_test,y_pred))
print('MSE',metrics.mean_squared_error(y_test,y_pred))
print('RMSE',np.sqrt(metrics.mean_squared_error(y_test,y_pred)))
# Out:
# MAE 856160.9537535122
# MSE 1404963758407.3252
# RMSE 1185311.6714212026

# %%
sns.distplot((y_pred),bins=50)
