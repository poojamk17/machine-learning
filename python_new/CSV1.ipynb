# %% [markdown]
# # airlines

# %%
import pandas as pd
import numpy as np
df=pd.read_csv('airline-safety.csv')
df
# Out:
#                        airline  avail_seat_km_per_week  incidents_85_99  \
# 0                   Aer Lingus               320906734                2
# 1                    Aeroflot*              1197672318               76
# 2        Aerolineas Argentinas               385803648                6
# 3                  Aeromexico*               596871813                3
# 4                   Air Canada              1865253802                2
# 5                   Air France              3004002661               14
# 6                   Air India*               869253552                2
# 7             Air New Zealand*               710174817                3
# 8             Alaska Airlines*               965346773                5
# 9                     Alitalia               698012498                7
# 10          All Nippon Airways              1841234177                3
# 11                   American*              5228357340               21
# ...

# %%
df.shape
# Out:
# (56, 8)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 56 entries, 0 to 55
# Data columns (total 8 columns):
# airline                   56 non-null object
# avail_seat_km_per_week    56 non-null int64
# incidents_85_99           56 non-null int64
# fatal_accidents_85_99     56 non-null int64
# fatalities_85_99          56 non-null int64
# incidents_00_14           56 non-null int64
# fatal_accidents_00_14     56 non-null int64
# fatalities_00_14          56 non-null int64
# dtypes: int64(7), object(1)
# memory usage: 3.6+ KB

# %%
df.groupby('incidents_85_99').mean()[['fatalities_85_99']]
# Out:
#                  fatalities_85_99
# incidents_85_99
# 0                        0.000000
# 1                        0.571429
# 2                       83.666667
# 3                       86.250000
# 4                       74.000000
# 5                       93.500000
# 6                        1.000000
# 7                      122.200000
# 8                      197.200000
# 9                       82.000000
# 10                     260.000000
# 12                     480.000000
# 14                      79.000000
# 16                     224.000000
# 19                     319.000000
# 21                     101.000000
# 24                     407.000000
# 25                     167.000000
# 76                     128.000000

# %%
df['accidents_in_2014']=df.apply(lambda c: 'low' if c.fatal_accidents_85_99<c.fatal_accidents_00_14 else 'high', axis=1)#6Q
df
# Out:
#                        airline  avail_seat_km_per_week  incidents_85_99  \
# 0                   Aer Lingus               320906734                2
# 1                    Aeroflot*              1197672318               76
# 2        Aerolineas Argentinas               385803648                6
# 3                  Aeromexico*               596871813                3
# 4                   Air Canada              1865253802                2
# 5                   Air France              3004002661               14
# 6                   Air India*               869253552                2
# 7             Air New Zealand*               710174817                3
# 8             Alaska Airlines*               965346773                5
# 9                     Alitalia               698012498                7
# 10          All Nippon Airways              1841234177                3
# 11                   American*              5228357340               21
# ...

# %%
df['death_rate']=df.apply(lambda c: 'low' if c.fatalities_85_99<c.fatalities_00_14 else 'high', axis=1)#6Q
df
# Out:
#                        airline  avail_seat_km_per_week  incidents_85_99  \
# 0                   Aer Lingus               320906734                2
# 1                    Aeroflot*              1197672318               76
# 2        Aerolineas Argentinas               385803648                6
# 3                  Aeromexico*               596871813                3
# 4                   Air Canada              1865253802                2
# 5                   Air France              3004002661               14
# 6                   Air India*               869253552                2
# 7             Air New Zealand*               710174817                3
# 8             Alaska Airlines*               965346773                5
# 9                     Alitalia               698012498                7
# 10          All Nippon Airways              1841234177                3
# 11                   American*              5228357340               21
# ...

# %%
df.groupby('fatalities_85_99').max()
# Out:
#                                      airline  avail_seat_km_per_week  \
# fatalities_85_99
# 0                            Virgin Atlantic              3276525770
# 1                         All Nippon Airways              1841234177
# 2                                 Lufthansa*              3426529504
# 3                                       TACA              1874561773
# 4                                      El Al               335448023
# 6                         Singapore Airlines              2376857805
# 14                     Sri Lankan / AirLanka               325582976
# 16                                    Condor               417982610
# 21                              LAN Airlines              1001965891
# 34                         Malaysia Airlines              1039171244
# 47                                      COPA               550491507
# 50                                  Alitalia               698012498
# ...

# %%
df.groupby('fatal_accidents_85_99').max()
# Out:
#                                           airline  avail_seat_km_per_week  \
# fatal_accidents_85_99
# 0                                 Virgin Atlantic              3276525770
# 1                                 Xiamen Airlines              3426529504
# 2                              Singapore Airlines              2376857805
# 3                                Vietnam Airlines              1946098294
# 4                                    Thai Airways              3004002661
# 5                                      Korean Air              5228357340
# 6                                  China Airlines               813216487
# 7                      US Airways / America West*              2455687887
# 8                           United / Continental*              7139291291
# 12                             Delta / Northwest*              6525658894
# 14                                      Aeroflot*              1197672318
#
# ...

# %%
df[(df['fatalities_85_99'].max()) & (df['fatal_accidents_85_99'].max())][['airline']]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2656             try:
# -> 2657                 return self._engine.get_loc(key)
#    2658             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 6
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-9-6d0fe9e3379c> in <module>
# ...

# %% [markdown]
# ###### to find max of fatalities_85_99 and print airline

# %%
n=df['fatalities_85_99'].max() #method 1
n
# Out:
# 535

# %%
df[df['fatalities_85_99']==n][['airline']]
# Out:
#            airline
# 16  China Airlines

# %%
df[df['fatalities_85_99']==df['fatalities_85_99'].max()][['airline']] #method 2 in one line
# Out:
#            airline
# 16  China Airlines

# %%
df1=df.groupby('fatalities_85_99').max() #method 3 (grp it and last as high value print it) 
df1.tail(1)[['airline']]
# Out:
#                          airline
# fatalities_85_99
# 535               China Airlines

# %%
df['inc']=df.apply(lambda c: c.fatal_accidents_85_99-c.fatal_accidents_00_14, axis=1)
df
# Out:
#                        airline  avail_seat_km_per_week  incidents_85_99  \
# 0                   Aer Lingus               320906734                2
# 1                    Aeroflot*              1197672318               76
# 2        Aerolineas Argentinas               385803648                6
# 3                  Aeromexico*               596871813                3
# 4                   Air Canada              1865253802                2
# 5                   Air France              3004002661               14
# 6                   Air India*               869253552                2
# 7             Air New Zealand*               710174817                3
# 8             Alaska Airlines*               965346773                5
# 9                     Alitalia               698012498                7
# 10          All Nippon Airways              1841234177                3
# 11                   American*              5228357340               21
# ...

# %%
df['inc%']=df.apply(lambda c: (c.inc/c.fatal_accidents_85_99)*100 if c.fatal_accidents_85_99!=0 else 0,axis=1)
df
# Out:
#                        airline  avail_seat_km_per_week  incidents_85_99  \
# 0                   Aer Lingus               320906734                2
# 1                    Aeroflot*              1197672318               76
# 2        Aerolineas Argentinas               385803648                6
# 3                  Aeromexico*               596871813                3
# 4                   Air Canada              1865253802                2
# 5                   Air France              3004002661               14
# 6                   Air India*               869253552                2
# 7             Air New Zealand*               710174817                3
# 8             Alaska Airlines*               965346773                5
# 9                     Alitalia               698012498                7
# 10          All Nippon Airways              1841234177                3
# 11                   American*              5228357340               21
# ...

# %%
df[df['inc%']==df['inc%'].max()][['airline']]
# Out:
#                   airline
# 3             Aeromexico*
# 9                Alitalia
# 10     All Nippon Airways
# 13                Avianca
# 17                 Condor
# 18                   COPA
# 21                  El Al
# 27                 Iberia
# 28         Japan Airlines
# 30                   KLM*
# 31             Korean Air
# 32           LAN Airlines
# 33             Lufthansa*
# 38        Royal Air Maroc
# 40          Saudi Arabian
# 42          South African
# 44  Sri Lankan / AirLanka
# 45                 SWISS*
# 53       Vietnam Airlines
# 55        Xiamen Airlines

# %%
df['increased?']=df.apply(lambda c: 'dec' if c.inc<=0  else 'inc', axis=1)#6Q
df
# Out:
#                        airline  avail_seat_km_per_week  incidents_85_99  \
# 0                   Aer Lingus               320906734                2
# 1                    Aeroflot*              1197672318               76
# 2        Aerolineas Argentinas               385803648                6
# 3                  Aeromexico*               596871813                3
# 4                   Air Canada              1865253802                2
# 5                   Air France              3004002661               14
# 6                   Air India*               869253552                2
# 7             Air New Zealand*               710174817                3
# 8             Alaska Airlines*               965346773                5
# 9                     Alitalia               698012498                7
# 10          All Nippon Airways              1841234177                3
# 11                   American*              5228357340               21
# ...

# %%
if df['increased?']==dec
# Out:
#   File "<ipython-input-18-3f431774fe9c>", line 1
#     if df['increased?']==dec
#                              ^
# SyntaxError: invalid syntax

# %%
dec=df['inc'][df['inc']<0].count()
dec
# Out:
# 6

# %%
inc=df['inc'][df['inc']>0].count()
inc
# Out:
# 36

# %%
not_change=56-(dec-inc)
not_change
# Out:
# 86

# %%
len(df[df['inc']>0])#m2
# Out:
# 36

# %%
df.apply(lambda x:'increased' if x.fatal_accidents_00_14>x.fatal_accidents_85_99 else('not_changed' if x.fatal_accidents_00_14==x.fatal_accidents_85_99 else 'dec'),axis=1)
# Out:
# 0     not_changed
# 1             dec
# 2     not_changed
# 3             dec
# 4     not_changed
# 5             dec
# 6     not_changed
# 7       increased
# 8       increased
# 9             dec
# 10            dec
# 11            dec
# 12    not_changed
# 13            dec
# 14    not_changed
# 15    not_changed
# 16            dec
# 17            dec
# 18            dec
# 19            dec
# 20            dec
# 21            dec
# 22            dec
# 23    not_changed
# 24            dec
# 25      increased
# 26    not_changed
# 27            dec
# 28            dec
# 29      increased
# 30            dec
# 31            dec
# 32            dec
# 33            dec
# 34      increased
# 35            dec
# 36            dec
# 37    not_changed
# 38            dec
# 39      increased
# 40            dec
# 41            dec
# 42            dec
# 43    not_changed
# 44            dec
# 45            dec
# 46    not_changed
# 47            dec
# 48    not_changed
# 49            dec
# ...

# %%
# Out:
# 6
