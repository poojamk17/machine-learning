# %% [markdown]
# #### 7.	Plot a bar chart showing runs scored on the x-axis and frequency/count on the y-axis. In which bucket has he scored runs the most often?

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
df=pd.read_csv('ODI_score.csv')
df
# Out:
#      Unnamed: 0  Runs  Mins   BF  4s  6s      SR  Pos       Dismissal  Inns  \
# 0             1     0     0    2   0   0    0.00    5          caught     2
# 1             2     0     2    2   0   0    0.00    5          caught     2
# 2             3    36    51   39   5   0   92.30    6          caught     1
# 3             4    19    38   35   1   1   54.28    4          bowled     2
# 4             5    31    31   26   3   0  119.23    6          bowled     2
# 5             6    36     0   22   3   2  163.63    5          bowled     1
# 6             7    53     0   41   7   1  129.26    5          bowled     2
# 7             8    30     0   29   1   2  103.44    5          caught     1
# 8             9     0     0    0   0   0    0.00    0               0     2
# 9            10     4     0   11   0   0   36.36    5             lbw     2
# 10           11    53     0   70   2   0   75.71    4             lbw     2
# ...

# %%
pd.to_numeric(df['Runs'],errors='coerce')
# Out:
# 0        0
# 1        0
# 2       36
# 3       19
# 4       31
# 5       36
# 6       53
# 7       30
# 8        0
# 9        4
# 10      53
# 11      62
# 12       4
# 13       1
# 14      36
# 15      57
# 16      21
# 17      31
# 18       4
# 19      69
# 20      11
# 21      84
# 22      39
# 23      15
# 24      10
# 25      22
# 26      21
# 27      32
# 28      23
# 29      21
#       ...
# 265     20
# 266    163
# 267     27
# 268    138
# 269     14
# 270      4
# 271     32
# 272     40
# 273    175
# 274     10
# 275     69
# 276     43
# 277     96
# 278      8
# 279      4
# 280    200
# 281      7
# 282     24
# 283     28
# 284     38
# 285     27
# 286    111
# 287      2
# 288     53
# 289     85
# 290     18
# 291      2
# 292      3
# 293     14
# 294    114
# Name: Runs, Length: 295, dtype: int64

# %%
a=df['Runs'].value_counts()
a
# Out:
# 1      16
# 0      15
# 2      14
# 4       9
# 21      8
# 8       7
# 5       6
# 6       6
# 11      6
# 36      6
# 3       6
# 30      5
# 14      5
# 27      5
# 65      5
# 62      5
# 18      5
# 15      5
# 100     5
# 7       5
# 39      4
# 32      4
# 53      4
# 31      4
# 12      4
# 28      4
# 35      3
# 34      3
# 29      3
# 82      3
#        ..
# 128     1
# 137     1
# 138     1
# 139     1
# 141     1
# 146     1
# 163     1
# 175     1
# 97      1
# 95      1
# 50      1
# 94      1
# 52      1
# 57      1
# 186     1
# 64      1
# 66      1
# 71      1
# 72      1
# 74      1
# 79      1
# 81      1
# 84      1
# 85      1
# 86      1
# 87      1
# 89      1
# 90      1
# 91      1
# 60      1
# Name: Runs, Length: 105, dtype: int64

# %%
a.plot(kind='bar')

# %%
a.plot(kind='hist')

# %%
c=df['4s'].value_counts()
c
# Out:
# 0     72
# 1     37
# 2     29
# 3     25
# 4     17
# 5     16
# 9     15
# 6     14
# 7     13
# 8     13
# 10    11
# 13     8
# 12     5
# 11     4
# 15     4
# 16     4
# 14     3
# 19     2
# 20     1
# 17     1
# 25     1
# Name: 4s, dtype: int64

# %%
c.plot(kind='bar')

# %%
c.plot(kind='hist')

# %%
c.plot.hist(bins=40)

# %%
c.plot.hist(bins=[0,10,20,30,40,50])

# %%
c.plot.hist(bins=[0,10,20,30,40,50])
plt.yscale('log')
plt.show()

# %%
c.plot.hist(bins=30)
plt.yscale('log')
plt.show()

# %% [markdown]
# ### 11.	The variation in the number of shares is larger for:.

# %%
df1=pd.read_csv('popularity.csv')
df1
# Out:
#                                                      url   timedelta  \
# 0      http://mashable.com/2013/01/07/amazon-instant-...       731.0
# 1      http://mashable.com/2013/01/07/ap-samsung-spon...       731.0
# 2      http://mashable.com/2013/01/07/apple-40-billio...       731.0
# 3      http://mashable.com/2013/01/07/astronaut-notre...       731.0
# 4       http://mashable.com/2013/01/07/att-u-verse-apps/       731.0
# 5       http://mashable.com/2013/01/07/beewi-smart-toys/       731.0
# 6      http://mashable.com/2013/01/07/bodymedia-armba...       731.0
# 7       http://mashable.com/2013/01/07/canon-poweshot-n/       731.0
# 8      http://mashable.com/2013/01/07/car-of-the-futu...       731.0
# 9      http://mashable.com/2013/01/07/chuck-hagel-web...       731.0
# 10     http://mashable.com/2013/01/07/cosmic-events-d...       731.0
# 11      http://mashable.com/2013/01/07/crayon-creatures/       731.0
# 12         http://mashable.com/2013/01/07/creature-cups/       731.0
# ...

# %%
df1.isnull().sum()
# Out:
# url                               0
#  timedelta                        0
#  n_tokens_title                   0
#  n_tokens_content                 0
#  n_unique_tokens                  0
#  n_non_stop_words                 0
#  n_non_stop_unique_tokens         0
#  num_hrefs                        0
#  num_self_hrefs                   0
#  num_imgs                         0
#  num_videos                       0
#  average_token_length             0
#  num_keywords                     0
#  data_channel_is_lifestyle        0
#  data_channel_is_entertainment    0
#  data_channel_is_bus              0
#  data_channel_is_socmed           0
#  data_channel_is_tech             0
#  data_channel_is_world            0
#  kw_min_min                       0
#  kw_max_min                       0
#  kw_avg_min                       0
#  kw_min_max                       0
#  kw_max_max                       0
#  kw_avg_max                       0
#  kw_min_avg                       0
# ...

# %%
df1[' is_weekend'].value_counts()
# Out:
# 0.0    34454
# 1.0     5190
# Name:  is_weekend, dtype: int64

# %%
df1[' weekday_is_sunday'].value_counts()
# Out:
# 0.0    36907
# 1.0     2737
# Name:  weekday_is_sunday, dtype: int64

# %%
a=df1[df1[' is_weekend']==1][[' shares']].mean()
a
# Out:
#  shares    3903.394412
# dtype: float64

# %%
a=df1[df1[' is_weekend']==1][[' shares']]
sns.boxplot(a,showfliers=False)

# %%
z=df1[df1[' weekday_is_monday']==1][[' shares']]
sns.boxplot(z,showfliers=False)

# %%
y=df1[df1[' weekday_is_tuesday']==1][[' shares']]
sns.boxplot(y,showfliers=False)

# %%
x=df1[df1[' weekday_is_wednesday']==1][[' shares']]
sns.boxplot(x,showfliers=False)

# %%
w=df1[df1[' weekday_is_thursday']==1][[' shares']]
sns.boxplot(w,showfliers=False)

# %%
v=df1[df1[' weekday_is_friday']==1][[' shares']]
sns.boxplot(v,showfliers=False)

# %%
u=df1[df1[' weekday_is_saturday']==1][[' shares']]
sns.boxplot(u,showfliers=False)

# %%
t=df1[df1[' weekday_is_sunday']==1][[' shares']]
sns.boxplot(t,showfliers=False)

# %% [markdown]
# #### 12.	Say you want to compare the number of shares of articles across weekdays. Select the correct statement
# #### ANS: C.	There is no significant difference in either the median or the spread of the number of shares across weekdays

# %%
b=df1[df1[' weekday_is_monday']==1][[' shares']].mean()
b
# Out:
#  shares    3647.025822
# dtype: float64

# %%
c=df1[df1[' weekday_is_tuesday']==1][[' shares']].mean()
c
# Out:
#  shares    3202.500677
# dtype: float64

# %%
d=df1[df1[' weekday_is_wednesday']==1][[' shares']].mean()
d
# Out:
#  shares    3303.40538
# dtype: float64

# %%
e=df1[df1[' weekday_is_thursday']==1][[' shares']].mean()
e
# Out:
#  shares    3178.599147
# dtype: float64

# %%
f=df1[df1[' weekday_is_friday']==1][[' shares']].mean()
f
# Out:
#  shares    3285.181021
# dtype: float64

# %%
g=df1[df1[' weekday_is_saturday']==1][[' shares']].mean()
g
# Out:
#  shares    4078.185079
# dtype: float64

# %%
h=df1[df1[' weekday_is_sunday']==1][[' shares']].mean()
h
# Out:
#  shares    3746.740592
# dtype: float64

# %%
df1.columns
# Out:
# Index(['url', ' timedelta', ' n_tokens_title', ' n_tokens_content',
#        ' n_unique_tokens', ' n_non_stop_words', ' n_non_stop_unique_tokens',
#        ' num_hrefs', ' num_self_hrefs', ' num_imgs', ' num_videos',
#        ' average_token_length', ' num_keywords', ' data_channel_is_lifestyle',
#        ' data_channel_is_entertainment', ' data_channel_is_bus',
#        ' data_channel_is_socmed', ' data_channel_is_tech',
#        ' data_channel_is_world', ' kw_min_min', ' kw_max_min', ' kw_avg_min',
#        ' kw_min_max', ' kw_max_max', ' kw_avg_max', ' kw_min_avg',
#        ' kw_max_avg', ' kw_avg_avg', ' self_reference_min_shares',
#        ' self_reference_max_shares', ' self_reference_avg_sharess',
#        ' weekday_is_monday', ' weekday_is_tuesday', ' weekday_is_wednesday',
#        ' weekday_is_thursday', ' weekday_is_friday', ' weekday_is_saturday',
#        ' weekday_is_sunday', ' is_weekend', ' LDA_00', ' LDA_01', ' LDA_02',
# ...

# %%
li=[' weekday_is_monday',' weekday_is_tuesday',' weekday_is_wednesday',' weekday_is_thursday',' weekday_is_friday']
li1=[3647.025822,3202.500677,3303.40538,3178.599147,3285.181021]
sns.boxplot(x=li,y=li1)

# %%
d=pd.DataFrame(li1,index=[' weekday_is_monday',' weekday_is_tuesday',' weekday_is_wednesday',' weekday_is_thursday',' weekday_is_friday'],columns=['a'])
d
# Out:
#                                  a
#  weekday_is_monday     3647.025822
#  weekday_is_tuesday    3202.500677
#  weekday_is_wednesday  3303.405380
#  weekday_is_thursday   3178.599147
#  weekday_is_friday     3285.181021

# %%
sns.boxplot(d)

# %%
l=[4078.185079,3746.740592]
d1=pd.DataFrame(l,index=[' weekday_is_saturday',' weekday_is_sunday'],columns=['b'])
d1
# Out:
#                                 b
#  weekday_is_saturday  4078.185079
#  weekday_is_sunday    3746.740592

# %%
sns.boxplot(d1)

# %% [markdown]
# #### 11.	The variation in the number of shares is larger for:.
# #### ANS: B.	Weekends

# %% [markdown]
# ##### to remove outlaier use showfliers=false

# %%
df1[' data_channel_is_lifestyle'].value_counts()
# Out:
# 0.0    37545
# 1.0     2099
# Name:  data_channel_is_lifestyle, dtype: int64

# %%
a=df1[df1[' data_channel_is_lifestyle']==1][' shares']
sns.boxplot(a,showfliers=False)

# %%
b=df1[df1[' data_channel_is_tech']==1][' shares']
sns.boxplot(b,showfliers=False)

# %%
c=df1[df1[' data_channel_is_socmed']==1][' shares']
sns.boxplot(c,showfliers=False)

# %%
d=df1[df1[' data_channel_is_world']==1][' shares']
sns.boxplot(d,showfliers=False)

# %% [markdown]
# #### 13.	Create boxplots for shares vs the channel types and answer which types of articles are most likely to reach 2500 shares?
# #### ANS: C.	Social Media

# %%
sns.boxplot(df1[' data_channel_is_lifestyle'],df1[' shares'],showfliers=False)

# %%
t
# Out:
#         shares
# 331       7900
# 332        731
# 333       1900
# 334       3100
# 335       1900
# 336       9700
# 337       3400
# 338        894
# 339       1300
# 340       2100
# 341      12100
# 342       1400
# 343       3700
# 344       2200
# 345       1300
# 346       1600
# 347       1400
# 348      14300
# 349      33100
# 350       3400
# 351       5400
# 352       5600
# 353        618
# 354       2300
# 723       9800
# 724       1700
# 725       3900
# 726       4200
# 727       1600
# 728       3500
# ...        ...
# 39202     1400
# 39203     2700
# 39204     1500
# 39205     1700
# 39206     3700
# 39492     1900
# 39493     2400
# 39494     2800
# 39495     2400
# 39496     1400
# 39497     1400
# 39498     1900
# 39499     1600
# 39500    25600
# 39501     1100
# 39502     2600
# 39503    11700
# 39504     3500
# 39505     1000
# 39506     2300
# 39507     3100
# 39508     1300
# 39509     1500
# 39510     1900
# 39511     4000
# 39512     1700
# ...

# %%
bx=[t,u,v,w,x,y,z]
plt.boxplot(bx,patch_artist=True,labels=['monday','tuesday','wednesday','thursday','friday','saturday','sunday'])
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-171-86cad2c6792d> in <module>
#       1 bx=[t,u,v,w,x,y,z]
# ----> 2 plt.boxplot(bx,patch_artist=True,labels=['monday','tuesday','wednesday','thursday','friday','saturday','sunday'])
#       3 plt.show()
#
# ~\Anaconda3\lib\site-packages\matplotlib\pyplot.py in boxplot(x, notch, sym, vert, whis, positions, widths, patch_artist, bootstrap, usermedians, conf_intervals, meanline, showmeans, showcaps, showbox, showfliers, boxprops, labels, flierprops, medianprops, meanprops, capprops, whiskerprops, manage_ticks, autorange, zorder, data)
#    2471         whiskerprops=whiskerprops, manage_ticks=manage_ticks,
#    2472         autorange=autorange, zorder=zorder, **({"data": data} if data
# -> 2473         is not None else {}))
#    2474
#    2475
#
# ...

# %%
bx=[b,c,d,e,f,g,h]
plt.boxplot(bx,patch_artist=True,labels=['monday','tuesday','wednesday','thursday','friday','saturday','sunday'])
plt.show()

# %%
fig=plt.figure(1,figsize=(9,6))
ax=fig.add_subplot(111)
bp=ax.boxplot(bx)

# %%
def remove_outlier(df_in, col_name):
    q1=df_in[col_name].quantile(0.25)
    q3=df_in[col_name].quantile(0.75)
    iqr=q3-q1 #Interquartile range
    fence_low=q1-1.5*iqr
    fence_high=q3+1.5*iqr
    df_out=df_in[(df_in[col_name] > fence_low) & (df_in[col_name] < fence_high)]
    return df_out

re_dat = remove_outlier(df1,' weekday_is_monday')
re_dat
# Out:
# Empty DataFrame
# ...
